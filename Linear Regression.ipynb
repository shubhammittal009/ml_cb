# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from jupyterthemes import jtplot
jtplot.style()

# %%
X = np.random.randn(100)

# %%
e = np.random.randn(100)
Y = 2*X + 5 + 0.3*e

# %%
plt.scatter(X,Y)
plt.xlabel("House Area")
plt.ylabel("price")
plt.show()

# %%
theta = np.zeros((2,))
print(theta)
# Out:
# [0. 0.]

# %%
def grad(X,Y,theta):
    
    m = X.shape[0]
    grad = np.zeros((2,))
    
    for i in range(m):
        yi = theta[1]*X[i] + theta[0]
        grad[0] += 2*(yi - Y[i])
        grad[1] += 2*(yi - Y[i])*X[i]
    
    return grad

# %%
def total_error(X,Y,theta):
    m = X.shape[0]
    e = 0 
    for i in range(m):
        yi = theta[1]*X[i] + theta[0]
        e += (yi-Y[i])**2
    
    return e

# %%
def gradientDescent(X,Y,learning_rate=0.001,max_steps=80):
    theta = np.zeros((2,))
    error_list = [] 
    theta_list = []
    
    for i in range(max_steps):
        #update theta
        g = grad(X,Y,theta) 
        theta[0] = theta[0] - learning_rate*g[0]
        theta[1] = theta[1] - learning_rate*g[1]
        error = total_error(X,Y,theta)
        error_list.append(error)
        theta_list.append(theta)
        
    return theta,theta_list,error_list

# %%
theta,theta_list,error_list = gradientDescent(X,Y)

# %%
plt.plot(error_list)
plt.show()

# %%
theta
# Out:
# array([4.99819246, 1.98818121])

# %%
def predict(X_Test,theta):
    return theta[0] + theta[1]*X_Test

# %%
X_Test = np.arange(-3,5)

# %%
print(X_Test)
Y_Pred = predict(X_Test,theta)
print(Y_Pred)
# Out:
# [-3 -2 -1  0  1  2  3  4]
# [-0.96635117  1.02183004  3.01001125  4.99819246  6.98637367  8.97455488
#  10.96273609 12.9509173 ]

# %%
plt.scatter(X,Y)
plt.plot(X_Test,Y_Pred,color='orange')
plt.show()
