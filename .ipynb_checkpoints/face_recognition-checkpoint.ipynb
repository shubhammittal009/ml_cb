# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
# Read an image
img = cv.imread('dataset/night.jpeg')

new_img = cv.cvtColor(img,cv.COLOR_BGR2RGB)

# %%
plt.imshow(img)
plt.show()
plt.imshow(new_img)
plt.show()

# %%
img.shape
# Out:
# (333, 500, 3)

# %%
plt.imshow(img[...,[2,1,0]])
plt.show()
