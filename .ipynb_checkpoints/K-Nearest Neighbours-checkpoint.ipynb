# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from jupyterthemes import jtplot
jtplot.style()

# %%
apples_data = np.random.multivariate_normal(mean=[5,7],cov=[[1.0,0.5],[0.5,1.2]],size=100)
# print(apples_data)

# %%
oranges_data = np.random.multivariate_normal(mean=[10,12],cov=[[2.0,-0.5],[-0.5,1.0]],size=900)
# print(oranges_data)

# %%
print(apples_data[:5,:])
# Out:
# [[5.22481421 9.16623906]
#  [6.36578269 7.39007026]
#  [4.83382485 8.1001927 ]
#  [5.74386727 6.8418357 ]
#  [3.97398393 7.38022439]]

# %%
print(oranges_data[:5,:])
# Out:
# [[10.02172836 12.11246906]
#  [10.75135741 11.99137535]
#  [10.53066006 10.87594701]
#  [12.48404334 10.16662877]
#  [ 8.58975945 11.660913  ]]

# %%
plt.scatter(oranges_data[:,0],oranges_data[:,1],label="apples")
plt.scatter(apples_data[:,0],apples_data[:,1],label="orange")
plt.xlabel("Sweetness")
plt.ylabel("Nutrition")
plt.legend()
plt.show()
