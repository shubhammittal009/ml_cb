# %%
import glob
import pickle
import numpy
from music21 import converter, instrument, note, chord, stream
from keras.models import Sequential, load_model
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Activation
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint, EarlyStopping
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Get Notes from Music Files

# %%
midi = converter.parse("midi_songs/dontbeafraid.mid")

# %%
midi
# Out:
# <music21.stream.Score 0x7f9f16ee8358>

# %%
midi.show('midi')
# Out:
#                 <div id='midiPlayerDiv8828'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv8828');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>

# %%
midi.show('text')
# Out:
# {0.0} <music21.stream.Part 0x7f9f16a9acf8>
#     {0.0} <music21.instrument.Piano 'Piano'>
#     {0.0} <music21.tempo.MetronomeMark Quarter=163.0>
#     {0.0} <music21.tempo.MetronomeMark Quarter=163.0>
#     {0.0} <music21.key.Key of d minor>
#     {0.0} <music21.meter.TimeSignature 5/4>
#     {0.0} <music21.stream.Voice 0x7f9f16c9ecf8>
#         {0.0} <music21.chord.Chord A3 D4>
#         {1.0} <music21.chord.Chord A3 D4>
#         {1.5} <music21.chord.Chord A3 D4>
#         {2.5} <music21.chord.Chord A3 D4>
#         {3.0} <music21.chord.Chord A3 D4>
#         {4.0} <music21.chord.Chord A3 D4>
#         {5.0} <music21.chord.Chord A3 C4 D4>
#         {6.0} <music21.chord.Chord A3 C4 D4>
#         {6.5} <music21.chord.Chord A3 C4 D4>
#         {7.5} <music21.chord.Chord A3 C4 D4>
#         {8.0} <music21.chord.Chord A3 C4 D4>
#         {9.0} <music21.chord.Chord A3 C4 D4>
#         {10.0} <music21.chord.Chord B3 D4>
#         {11.0} <music21.chord.Chord B3 D4>
#         {11.5} <music21.chord.Chord B3 D4>
#         {12.5} <music21.chord.Chord B3 D4>
#         {13.0} <music21.chord.Chord B3 D4>
#         {14.0} <music21.chord.Chord B3 D4>
#         {15.0} <music21.chord.Chord B-3 D4>
#         {16.0} <music21.chord.Chord B-3 D4>
#         {16.5} <music21.chord.Chord B-3 D4>
#         {17.5} <music21.chord.Chord B-3 D4>
#         {18.0} <music21.chord.Chord B-3 D4>
#         {19.0} <music21.chord.Chord B-3 D4>
#         {20.0} <music21.chord.Chord A3 D4>
#         {21.0} <music21.chord.Chord A3 D4>
#         {21.5} <music21.chord.Chord A3 D4>
#         {22.5} <music21.chord.Chord A3 D4>
#         {23.0} <music21.chord.Chord A3 D4>
#         {24.0} <music21.chord.Chord A3 D4>
#         {25.0} <music21.chord.Chord A3 C4 D4>
#         {26.0} <music21.chord.Chord A3 C4 D4>
#         {26.5} <music21.chord.Chord A3 C4 D4>
#         {27.5} <music21.chord.Chord A3 C4 D4>
#         {28.0} <music21.chord.Chord A3 C4 D4>
#         {29.0} <music21.chord.Chord A3 C4 D4>
#         {30.0} <music21.chord.Chord G3 B3 D4>
#         {31.0} <music21.chord.Chord G3 B3 D4>
#         {31.5} <music21.chord.Chord G3 B3 D4>
#         {32.5} <music21.chord.Chord G3 B3 D4>
#         {33.0} <music21.chord.Chord G3 B3 D4>
#         {34.0} <music21.chord.Chord G3 B3 D4>
#         {35.0} <music21.chord.Chord F3 B-3 D4>
#         {36.0} <music21.chord.Chord F3 B-3 D4>
#         {36.5} <music21.chord.Chord F3 B-3 D4>
#         {37.5} <music21.chord.Chord F3 B-3 D4>
#         {38.0} <music21.chord.Chord F3 B-3 D4>
#         {39.0} <music21.chord.Chord F3 B-3 D4>
#         {40.0} <music21.note.Note A>
#         {41.5} <music21.note.Note B>
#         {43.0} <music21.chord.Chord C5 A2>
#         {44.0} <music21.chord.Chord D5 A2>
#         {45.0} <music21.note.Note A>
#         {50.0} <music21.chord.Chord F4 A4>
#         {51.5} <music21.note.Note F>
#         {52.5} <music21.note.Note D>
#         {53.0} <music21.chord.Chord C5 E5 A2>
#         {54.0} <music21.chord.Chord D5 B5 A2>
#         {55.0} <music21.chord.Chord F5 D6>
#         {60.0} <music21.chord.Chord D5 B5>
#         {61.0} <music21.chord.Chord E5 C6>
#         {61.5} <music21.chord.Chord D5 B5>
#         {62.5} <music21.chord.Chord C5 A5>
#         {63.0} <music21.chord.Chord B4 G5>
#         {64.0} <music21.chord.Chord C5 A5>
#         {64.5} <music21.chord.Chord B4 G5>
#         {65.5} <music21.chord.Chord F4 D5>
#         {66.0} <music21.chord.Chord A4 F5>
#         {67.0} <music21.chord.Chord G4 E5>
#         {68.0} <music21.chord.Chord F4 D5>
#         {69.0} <music21.chord.Chord D4 B4>
#         {70.0} <music21.chord.Chord E4 C5 A2>
#         {71.5} <music21.chord.Chord A4 D5 A2>
#         {73.0} <music21.chord.Chord C5 E5 A2>
#         {74.0} <music21.chord.Chord D5 F#5 A2>
#         {75.0} <music21.chord.Chord C5 E5 A2>
#         {76.5} <music21.chord.Chord D5 F#5 A2>
#         {78.0} <music21.chord.Chord E5 G5 A2>
#         {79.0} <music21.chord.Chord F#5 A5 A2>
#         {80.0} <music21.note.Note A>
#         {81.5} <music21.note.Note B>
#         {83.0} <music21.chord.Chord C5 A2>
#         {84.0} <music21.chord.Chord D5 A2>
#         {85.0} <music21.note.Note A>
#         {90.0} <music21.chord.Chord F4 A4>
#         {91.5} <music21.note.Note F>
#         {92.5} <music21.note.Note D>
#         {93.0} <music21.chord.Chord C5 E5 A2>
#         {94.0} <music21.chord.Chord D5 B5 A2>
#         {95.0} <music21.chord.Chord F5 D6>
#         {100.0} <music21.note.Note B>
#         {100.5} <music21.note.Note B->
#         {101.0} <music21.note.Note B>
#         {101.5} <music21.note.Note C>
#         {102.0} <music21.note.Note B>
#         {102.5} <music21.note.Note C>
#         {103.0} <music21.note.Note D>
#         {103.5} <music21.note.Note G>
#         {104.0} <music21.note.Note A>
#         {104.5} <music21.note.Note F#>
#         {105.0} <music21.note.Note G>
#         {105.5} <music21.note.Note F#>
#         {106.0} <music21.note.Note G>
#         {106.5} <music21.note.Note A>
#         {107.0} <music21.note.Note B>
#         {107.5} <music21.note.Note A>
#         {108.0} <music21.note.Note B>
#         {108.5} <music21.note.Note C>
#         {109.0} <music21.note.Note D>
#         {109.5} <music21.note.Note B>
#         {110.0} <music21.chord.Chord E5 C6 A2>
#         {111.5} <music21.chord.Chord A4 D5 A2>
#         {113.0} <music21.chord.Chord C5 E5 A2>
#         {114.0} <music21.chord.Chord D5 F#5 A2>
#         {115.0} <music21.chord.Chord C5 E5 A2>
#         {116.5} <music21.chord.Chord D5 F#5 A2>
#         {118.0} <music21.chord.Chord E5 G5 A2>
#         {119.0} <music21.chord.Chord F#5 A5 A2>
#         {120.0} <music21.note.Note A>
#         {123.0} <music21.chord.Chord E4 A2>
#         {124.0} <music21.chord.Chord D4 A2>
#         {125.0} <music21.note.Note E>
#         {129.0} <music21.chord.Chord G4 A2>
#         {130.0} <music21.chord.Chord F#4 D3>
#         {135.0} <music21.note.Note D>
#         {138.0} <music21.chord.Chord E4 A2>
#         {139.0} <music21.chord.Chord F4 A2>
#         {140.0} <music21.chord.Chord E4 E3>
#         {145.0} <music21.chord.Chord A3 G3>
#         {148.0} <music21.chord.Chord A4 A2>
#         {149.0} <music21.chord.Chord G4 G2>
#         {150.0} <music21.chord.Chord A4 F#3>
#         {155.0} <music21.chord.Chord C4 A4>
#         {159.0} <music21.note.Note A>
#         {160.0} <music21.note.Note A>
#         {163.0} <music21.chord.Chord E5 A2>
#         {164.0} <music21.chord.Chord D5 A2>
#         {165.0} <music21.note.Note E>
#         {169.0} <music21.chord.Chord G5 A2>
#         {170.0} <music21.chord.Chord F#5 D3>
#         {175.0} <music21.note.Note D>
#         {178.0} <music21.chord.Chord F5 A2>
#         {179.0} <music21.chord.Chord G5 A2>
#         {180.0} <music21.chord.Chord D5 A3 D4>
#         {185.0} <music21.chord.Chord F5 A3 C4>
#         {190.0} <music21.chord.Chord B4 G5 G3 B3>
#         {195.0} <music21.chord.Chord B-4 F5 B-3 D4>
#         {200.0} <music21.note.Note A>
#         {203.0} <music21.chord.Chord E4 A2>
#         {204.0} <music21.chord.Chord D4 A2>
#         {205.0} <music21.note.Note E>
#         {209.0} <music21.chord.Chord G4 A2>
#         {210.0} <music21.chord.Chord F#4 D3>
#         {215.0} <music21.note.Note D>
#         {218.0} <music21.chord.Chord C4 A2>
#         {219.0} <music21.chord.Chord B3 A2>
#         {220.0} <music21.chord.Chord C5 F3>
#         {225.0} <music21.chord.Chord D5 F3>
#         {230.0} <music21.chord.Chord E5 F3>
#         {235.0} <music21.chord.Chord F5 F3>
#         {240.0} <music21.note.Note A>
#         {241.5} <music21.note.Note B>
#         {243.0} <music21.chord.Chord C5 A2>
#         {244.0} <music21.chord.Chord D5 A2>
#         {245.0} <music21.note.Note A>
#         {250.0} <music21.chord.Chord F4 A4>
#         {251.5} <music21.note.Note F>
#         {252.5} <music21.note.Note D>
#         {253.0} <music21.chord.Chord C5 E5 A2>
#         {254.0} <music21.chord.Chord D5 B5 A2>
#         {255.0} <music21.chord.Chord F5 D6>
#         {260.0} <music21.chord.Chord D5 B5>
#         {261.0} <music21.chord.Chord E5 C6>
#         {261.5} <music21.chord.Chord D5 B5>
#         {262.5} <music21.chord.Chord C5 A5>
#         {263.0} <music21.chord.Chord B4 G5>
#         {264.0} <music21.chord.Chord C5 A5>
#         {264.5} <music21.chord.Chord B4 G5>
#         {265.5} <music21.chord.Chord F4 D5>
#         {266.0} <music21.chord.Chord A4 F5>
#         {267.0} <music21.chord.Chord G4 E5>
#         {268.0} <music21.chord.Chord F4 D5>
#         {269.0} <music21.chord.Chord D4 B4>
#         {270.0} <music21.chord.Chord E4 C5 A2>
#         {271.5} <music21.chord.Chord A4 D5 A2>
#         {273.0} <music21.chord.Chord C5 E5 A2>
#         {274.0} <music21.chord.Chord D5 F#5 A2>
#         {275.0} <music21.chord.Chord C5 E5 A2>
#         {276.5} <music21.chord.Chord D5 F#5 A2>
#         {278.0} <music21.chord.Chord E5 G5 A2>
#         {279.0} <music21.chord.Chord F#5 A5 A2>
#         {280.0} <music21.note.Note A>
#         {281.5} <music21.note.Note B>
#         {283.0} <music21.chord.Chord C5 A2>
#         {284.0} <music21.chord.Chord D5 A2>
#         {285.0} <music21.note.Note A>
#         {290.0} <music21.chord.Chord F4 A4>
#         {291.5} <music21.note.Note F>
#         {292.5} <music21.note.Note D>
#         {293.0} <music21.chord.Chord C5 E5 A2>
#         {294.0} <music21.chord.Chord D5 B5 A2>
#         {295.0} <music21.chord.Chord F5 D6>
#         {300.0} <music21.note.Note B>
#         {300.5} <music21.note.Note B->
#         {301.0} <music21.note.Note B>
#         {301.5} <music21.note.Note C>
#         {302.0} <music21.note.Note B>
#         {302.5} <music21.note.Note C>
#         {303.0} <music21.note.Note D>
#         {303.5} <music21.note.Note G>
#         {304.0} <music21.note.Note A>
#         {304.5} <music21.note.Note F#>
#         {305.0} <music21.note.Note G>
#         {305.5} <music21.note.Note F#>
#         {306.0} <music21.note.Note G>
#         {306.5} <music21.note.Note A>
#         {307.0} <music21.note.Note B>
#         {307.5} <music21.note.Note A>
#         {308.0} <music21.note.Note B>
#         {308.5} <music21.note.Note C>
#         {309.0} <music21.note.Note D>
#         {309.5} <music21.note.Note B>
#         {310.0} <music21.chord.Chord E5 C6 A2>
#         {311.5} <music21.chord.Chord A4 D5 A2>
#         {313.0} <music21.chord.Chord C5 E5 A2>
#         {314.0} <music21.chord.Chord D5 F#5 A2>
#         {315.0} <music21.chord.Chord C5 E5 A2>
#         {316.5} <music21.chord.Chord D5 F#5 A2>
#         {318.0} <music21.chord.Chord E5 G5 A2>
#         {319.0} <music21.chord.Chord F#5 A5 A2>
#         {320.0} <music21.note.Note A>
#         {323.0} <music21.chord.Chord E4 A2>
#         {324.0} <music21.chord.Chord D4 A2>
#         {325.0} <music21.note.Note E>
#         {329.0} <music21.chord.Chord G4 A2>
#         {330.0} <music21.chord.Chord F#4 D3>
#         {335.0} <music21.note.Note D>
#         {338.0} <music21.chord.Chord E4 A2>
#         {339.0} <music21.chord.Chord F4 A2>
#         {340.0} <music21.chord.Chord E4 E3>
#         {345.0} <music21.chord.Chord A3 G3>
#         {348.0} <music21.chord.Chord A4 A2>
#         {349.0} <music21.chord.Chord G4 G2>
#         {350.0} <music21.chord.Chord A4 F#3>
#         {355.0} <music21.chord.Chord C4 A4>
#         {359.0} <music21.note.Note A>
#         {360.0} <music21.note.Note A>
#         {363.0} <music21.chord.Chord E5 A2>
#         {364.0} <music21.chord.Chord D5 A2>
#         {365.0} <music21.note.Note E>
#         {369.0} <music21.chord.Chord G5 A2>
#         {370.0} <music21.chord.Chord F#5 D3>
#         {375.0} <music21.note.Note D>
#         {378.0} <music21.chord.Chord F5 A2>
#         {379.0} <music21.chord.Chord G5 A2>
#         {380.0} <music21.chord.Chord D5 A3 D4>
#         {385.0} <music21.chord.Chord F5 A3 C4>
#         {390.0} <music21.chord.Chord B4 G5 G3 B3>
#         {395.0} <music21.chord.Chord B-4 F5 B-3 D4>
#         {400.0} <music21.note.Note A>
#         {403.0} <music21.chord.Chord E4 A2>
#         {404.0} <music21.chord.Chord D4 A2>
#         {405.0} <music21.note.Note E>
#         {409.0} <music21.chord.Chord G4 A2>
#         {410.0} <music21.chord.Chord F#4 D3>
#         {415.0} <music21.note.Note D>
#         {418.0} <music21.chord.Chord C4 A2>
#         {419.0} <music21.chord.Chord B3 A2>
#         {420.0} <music21.chord.Chord C5 F3>
#         {425.0} <music21.chord.Chord D5 F3>
#         {430.0} <music21.chord.Chord E5 F3>
#         {435.0} <music21.chord.Chord F5 F3>
#         {440.0} <music21.note.Note A>
#         {441.5} <music21.note.Note B>
#         {443.0} <music21.chord.Chord C5 A2>
#         {444.0} <music21.chord.Chord D5 A2>
#         {445.0} <music21.note.Note A>
#         {450.0} <music21.chord.Chord F4 A4>
#         {451.5} <music21.note.Note F>
#         {452.5} <music21.note.Note D>
#         {453.0} <music21.chord.Chord C5 E5 A2>
#         {454.0} <music21.chord.Chord D5 B5 A2>
#         {455.0} <music21.chord.Chord F5 D6>
#     {0.0} <music21.stream.Voice 0x7f9f16d28be0>
#         {0.0} <music21.note.Note D>
#         {5.0} <music21.note.Note D>
#         {10.0} <music21.note.Note D>
#         {15.0} <music21.note.Note D>
#         {20.0} <music21.note.Note D>
#         {25.0} <music21.note.Note D>
#         {30.0} <music21.note.Note D>
#         {35.0} <music21.note.Note D>
#         {40.0} <music21.note.Note E>
#         {45.0} <music21.note.Note E>
#         {45.5} <music21.note.Note E>
#         {46.0} <music21.note.Note E>
#         {46.5} <music21.chord.Chord E-4 A2>
#         {47.0} <music21.note.Note E->
#         {47.5} <music21.note.Note E->
#         {48.0} <music21.note.Note D>
#         {48.5} <music21.note.Note D>
#         {49.0} <music21.chord.Chord C4 A2>
#         {50.0} <music21.note.Note A>
#         {51.5} <music21.note.Note B>
#         {55.0} <music21.note.Note A>
#         {56.0} <music21.note.Note D>
#         {57.0} <music21.note.Note C>
#         {58.0} <music21.chord.Chord B4 A2>
#         {59.0} <music21.chord.Chord A4 A2>
#         {60.0} <music21.note.Note G>
#         {66.0} <music21.note.Note G>
#         {66.5} <music21.note.Note D>
#         {67.5} <music21.note.Note E>
#         {68.5} <music21.note.Note F>
#         {69.5} <music21.note.Note G>
#         {80.0} <music21.note.Note E>
#         {85.0} <music21.note.Note E>
#         {85.5} <music21.note.Note E>
#         {86.0} <music21.note.Note E>
#         {86.5} <music21.chord.Chord E-4 A2>
#         {87.0} <music21.note.Note E->
#         {87.5} <music21.note.Note E->
#         {88.0} <music21.note.Note D>
#         {88.5} <music21.note.Note D>
#         {89.0} <music21.chord.Chord C4 A2>
#         {90.0} <music21.note.Note A>
#         {91.5} <music21.note.Note B>
#         {95.0} <music21.note.Note A>
#         {96.5} <music21.note.Note A>
#         {97.5} <music21.note.Note A>
#         {98.0} <music21.note.Note A>
#         {99.0} <music21.note.Note E>
#         {100.0} <music21.note.Note B>
#         {101.5} <music21.note.Note A>
#         {103.0} <music21.note.Note G>
#         {104.0} <music21.note.Note D>
#         {105.0} <music21.note.Note D>
#         {106.5} <music21.note.Note C>
#         {108.0} <music21.note.Note B>
#         {120.0} <music21.note.Note E>
#         {125.0} <music21.note.Note G>
#         {130.0} <music21.note.Note A>
#         {131.5} <music21.note.Note A>
#         {133.0} <music21.note.Note A>
#         {134.0} <music21.note.Note A>
#         {135.0} <music21.note.Note F>
#         {140.0} <music21.note.Note A>
#         {141.5} <music21.note.Note A>
#         {143.0} <music21.note.Note A>
#         {144.0} <music21.note.Note A>
#         {145.0} <music21.note.Note A>
#         {146.5} <music21.note.Note A>
#         {150.0} <music21.note.Note D>
#         {153.0} <music21.chord.Chord C4 A2>
#         {154.0} <music21.chord.Chord B3 A2>
#         {155.0} <music21.note.Note F>
#         {160.0} <music21.note.Note E>
#         {165.0} <music21.note.Note G>
#         {170.0} <music21.note.Note A>
#         {171.5} <music21.note.Note A>
#         {173.0} <music21.note.Note A>
#         {174.0} <music21.note.Note A>
#         {175.0} <music21.note.Note F>
#         {180.0} <music21.note.Note A>
#         {190.0} <music21.note.Note D>
#         {191.5} <music21.note.Note D>
#         {193.0} <music21.note.Note D>
#         {194.0} <music21.note.Note D>
#         {195.0} <music21.note.Note D>
#         {196.5} <music21.note.Note D>
#         {198.0} <music21.note.Note D>
#         {199.0} <music21.note.Note D>
#         {200.0} <music21.note.Note E>
#         {205.0} <music21.note.Note G>
#         {210.0} <music21.note.Note A>
#         {211.5} <music21.note.Note A>
#         {213.0} <music21.note.Note A>
#         {214.0} <music21.note.Note A>
#         {215.0} <music21.note.Note F>
#         {220.0} <music21.note.Note F>
#         {221.5} <music21.note.Note F>
#         {223.0} <music21.note.Note F>
#         {224.0} <music21.note.Note F>
#         {225.0} <music21.note.Note F>
#         {226.5} <music21.note.Note F>
#         {228.0} <music21.note.Note F>
#         {229.0} <music21.note.Note F>
#         {230.0} <music21.note.Note F>
#         {231.5} <music21.note.Note F>
#         {233.0} <music21.note.Note F>
#         {234.0} <music21.note.Note F>
#         {235.0} <music21.note.Note F>
#         {236.5} <music21.note.Note F>
#         {238.0} <music21.note.Note F>
#         {239.0} <music21.note.Note F>
#         {240.0} <music21.note.Note E>
#         {245.0} <music21.note.Note E>
#         {245.5} <music21.note.Note E>
#         {246.0} <music21.note.Note E>
#         {246.5} <music21.chord.Chord E-4 A2>
#         {247.0} <music21.note.Note E->
#         {247.5} <music21.note.Note E->
#         {248.0} <music21.note.Note D>
#         {248.5} <music21.note.Note D>
#         {249.0} <music21.chord.Chord C4 A2>
#         {250.0} <music21.note.Note A>
#         {251.5} <music21.note.Note B>
#         {255.0} <music21.note.Note A>
#         {256.0} <music21.note.Note D>
#         {257.0} <music21.note.Note C>
#         {258.0} <music21.chord.Chord B4 A2>
#         {259.0} <music21.chord.Chord A4 A2>
#         {260.0} <music21.note.Note G>
#         {266.0} <music21.note.Note G>
#         {266.5} <music21.note.Note D>
#         {267.5} <music21.note.Note E>
#         {268.5} <music21.note.Note F>
#         {269.5} <music21.note.Note G>
#         {280.0} <music21.note.Note E>
#         {285.0} <music21.note.Note E>
#         {285.5} <music21.note.Note E>
#         {286.0} <music21.note.Note E>
#         {286.5} <music21.chord.Chord E-4 A2>
#         {287.0} <music21.note.Note E->
#         {287.5} <music21.note.Note E->
#         {288.0} <music21.note.Note D>
#         {288.5} <music21.note.Note D>
#         {289.0} <music21.chord.Chord C4 A2>
#         {290.0} <music21.note.Note A>
#         {291.5} <music21.note.Note B>
#         {295.0} <music21.note.Note A>
#         {296.5} <music21.note.Note A>
#         {297.5} <music21.note.Note A>
#         {298.0} <music21.note.Note A>
#         {299.0} <music21.note.Note E>
#         {300.0} <music21.note.Note B>
#         {301.5} <music21.note.Note A>
#         {303.0} <music21.note.Note G>
#         {304.0} <music21.note.Note D>
#         {305.0} <music21.note.Note D>
#         {306.5} <music21.note.Note C>
#         {308.0} <music21.note.Note B>
#         {320.0} <music21.note.Note E>
#         {325.0} <music21.note.Note G>
#         {330.0} <music21.note.Note A>
#         {331.5} <music21.note.Note A>
#         {333.0} <music21.note.Note A>
#         {334.0} <music21.note.Note A>
#         {335.0} <music21.note.Note F>
#         {340.0} <music21.note.Note A>
#         {341.5} <music21.note.Note A>
#         {343.0} <music21.note.Note A>
#         {344.0} <music21.note.Note A>
#         {345.0} <music21.note.Note A>
#         {346.5} <music21.note.Note A>
#         {350.0} <music21.note.Note D>
#         {353.0} <music21.chord.Chord C4 A2>
#         {354.0} <music21.chord.Chord B3 A2>
#         {355.0} <music21.note.Note F>
#         {360.0} <music21.note.Note E>
#         {365.0} <music21.note.Note G>
#         {370.0} <music21.note.Note A>
#         {371.5} <music21.note.Note A>
#         {373.0} <music21.note.Note A>
#         {374.0} <music21.note.Note A>
#         {375.0} <music21.note.Note F>
#         {380.0} <music21.note.Note A>
#         {390.0} <music21.note.Note D>
#         {391.5} <music21.note.Note D>
#         {393.0} <music21.note.Note D>
#         {394.0} <music21.note.Note D>
#         {395.0} <music21.note.Note D>
#         {396.5} <music21.note.Note D>
#         {398.0} <music21.note.Note D>
#         {399.0} <music21.note.Note D>
#         {400.0} <music21.note.Note E>
#         {405.0} <music21.note.Note G>
#         {410.0} <music21.note.Note A>
#         {411.5} <music21.note.Note A>
#         {413.0} <music21.note.Note A>
#         {414.0} <music21.note.Note A>
#         {415.0} <music21.note.Note F>
#         {420.0} <music21.note.Note F>
#         {421.5} <music21.note.Note F>
#         {423.0} <music21.note.Note F>
#         {424.0} <music21.note.Note F>
#         {425.0} <music21.note.Note F>
#         {426.5} <music21.note.Note F>
#         {428.0} <music21.note.Note F>
#         {429.0} <music21.note.Note F>
#         {430.0} <music21.note.Note F>
#         {431.5} <music21.note.Note F>
#         {433.0} <music21.note.Note F>
#         {434.0} <music21.note.Note F>
#         {435.0} <music21.note.Note F>
#         {436.5} <music21.note.Note F>
#         {438.0} <music21.note.Note F>
#         {439.0} <music21.note.Note F>
#         {440.0} <music21.note.Note E>
#         {445.0} <music21.note.Note E>
#         {445.5} <music21.note.Note E>
#         {446.0} <music21.note.Note E>
#         {446.5} <music21.chord.Chord E-4 A2>
#         {447.0} <music21.note.Note E->
#         {447.5} <music21.note.Note E->
#         {448.0} <music21.note.Note D>
#         {448.5} <music21.note.Note D>
#         {449.0} <music21.chord.Chord C4 A2>
#         {450.0} <music21.note.Note A>
#         {451.5} <music21.note.Note B>
#         {455.0} <music21.note.Note A>
#         {456.0} <music21.note.Note D>
#         {457.0} <music21.note.Note C>
#         {458.0} <music21.chord.Chord B4 A2>
#         {459.0} <music21.chord.Chord A4 A2>
#     {0.0} <music21.stream.Voice 0x7f9f16eb57f0>
#         {40.0} <music21.note.Note A>
#         {41.5} <music21.note.Note A>
#         {45.0} <music21.note.Note A>
#         {48.0} <music21.note.Note A>
#         {51.5} <music21.note.Note A>
#         {56.5} <music21.note.Note A>
#         {80.0} <music21.note.Note A>
#         {81.5} <music21.note.Note A>
#         {85.0} <music21.note.Note A>
#         {88.0} <music21.note.Note A>
#         {91.5} <music21.note.Note A>
#         {100.0} <music21.note.Note G>
#         {105.0} <music21.note.Note G>
#         {108.0} <music21.note.Note G>
#         {109.0} <music21.note.Note G>
#         {120.0} <music21.note.Note A>
#         {121.5} <music21.note.Note A>
#         {125.0} <music21.note.Note A>
#         {126.5} <music21.note.Note A>
#         {128.0} <music21.note.Note A>
#         {135.0} <music21.note.Note A>
#         {136.5} <music21.note.Note A>
#         {150.0} <music21.note.Note A>
#         {151.5} <music21.note.Note A>
#         {155.0} <music21.note.Note A>
#         {156.5} <music21.note.Note A>
#         {158.0} <music21.note.Note A>
#         {160.0} <music21.note.Note A>
#         {161.5} <music21.note.Note A>
#         {165.0} <music21.note.Note A>
#         {166.5} <music21.note.Note A>
#         {168.0} <music21.note.Note A>
#         {175.0} <music21.note.Note A>
#         {176.5} <music21.note.Note A>
#         {180.0} <music21.note.Note D>
#         {181.5} <music21.note.Note D>
#         {183.0} <music21.note.Note D>
#         {184.0} <music21.note.Note D>
#         {185.0} <music21.note.Note D>
#         {186.5} <music21.note.Note D>
#         {188.0} <music21.note.Note D>
#         {189.0} <music21.note.Note D>
#         {200.0} <music21.note.Note A>
#         {201.5} <music21.note.Note A>
#         {205.0} <music21.note.Note A>
#         {206.5} <music21.note.Note A>
#         {208.0} <music21.note.Note A>
#         {215.0} <music21.note.Note A>
#         {216.5} <music21.note.Note A>
#         {240.0} <music21.note.Note A>
#         {241.5} <music21.note.Note A>
#         {245.0} <music21.note.Note A>
#         {248.0} <music21.note.Note A>
#         {251.5} <music21.note.Note A>
#         {256.5} <music21.note.Note A>
#         {280.0} <music21.note.Note A>
#         {281.5} <music21.note.Note A>
#         {285.0} <music21.note.Note A>
#         {288.0} <music21.note.Note A>
#         {291.5} <music21.note.Note A>
#         {300.0} <music21.note.Note G>
#         {305.0} <music21.note.Note G>
#         {308.0} <music21.note.Note G>
#         {309.0} <music21.note.Note G>
#         {320.0} <music21.note.Note A>
#         {321.5} <music21.note.Note A>
#         {325.0} <music21.note.Note A>
#         {326.5} <music21.note.Note A>
#         {328.0} <music21.note.Note A>
#         {335.0} <music21.note.Note A>
#         {336.5} <music21.note.Note A>
#         {350.0} <music21.note.Note A>
#         {351.5} <music21.note.Note A>
#         {355.0} <music21.note.Note A>
#         {356.5} <music21.note.Note A>
#         {358.0} <music21.note.Note A>
#         {360.0} <music21.note.Note A>
#         {361.5} <music21.note.Note A>
#         {365.0} <music21.note.Note A>
#         {366.5} <music21.note.Note A>
#         {368.0} <music21.note.Note A>
#         {375.0} <music21.note.Note A>
#         {376.5} <music21.note.Note A>
#         {380.0} <music21.note.Note D>
#         {381.5} <music21.note.Note D>
#         {383.0} <music21.note.Note D>
#         {384.0} <music21.note.Note D>
#         {385.0} <music21.note.Note D>
#         {386.5} <music21.note.Note D>
#         {388.0} <music21.note.Note D>
#         {389.0} <music21.note.Note D>
#         {400.0} <music21.note.Note A>
#         {401.5} <music21.note.Note A>
#         {405.0} <music21.note.Note A>
#         {406.5} <music21.note.Note A>
#         {408.0} <music21.note.Note A>
#         {415.0} <music21.note.Note A>
#         {416.5} <music21.note.Note A>
#         {440.0} <music21.note.Note A>
#         {441.5} <music21.note.Note A>
#         {445.0} <music21.note.Note A>
#         {448.0} <music21.note.Note A>
#         {451.5} <music21.note.Note A>
#         {456.5} <music21.note.Note A>
#     {40.0} <music21.key.Key of a minor>
#     {60.0} <music21.meter.TimeSignature 6/8>
#     {66.0} <music21.meter.TimeSignature 4/4>
#     {70.0} <music21.meter.TimeSignature 5/4>
#     {260.0} <music21.meter.TimeSignature 6/8>
#     {266.0} <music21.meter.TimeSignature 4/4>
#     {270.0} <music21.meter.TimeSignature 5/4>

# %%
for i in midi.parts:
    print(i[0], i)
# Out:
# Piano <music21.stream.Part 0x7f9f16a9acf8>

# %%
for i in midi.flat:
    print(i)
# Out:
# Piano
# <music21.tempo.MetronomeMark Quarter=163.0>
# <music21.tempo.MetronomeMark Quarter=163.0>
# d minor
# <music21.meter.TimeSignature 5/4>
# <music21.chord.Chord A3 D4>
# <music21.note.Note D>
# <music21.chord.Chord A3 D4>
# <music21.chord.Chord A3 D4>
# <music21.chord.Chord A3 D4>
# <music21.chord.Chord A3 D4>
# <music21.chord.Chord A3 D4>
# <music21.chord.Chord A3 C4 D4>
# <music21.note.Note D>
# <music21.chord.Chord A3 C4 D4>
# <music21.chord.Chord A3 C4 D4>
# <music21.chord.Chord A3 C4 D4>
# <music21.chord.Chord A3 C4 D4>
# <music21.chord.Chord A3 C4 D4>
# <music21.chord.Chord B3 D4>
# <music21.note.Note D>
# <music21.chord.Chord B3 D4>
# <music21.chord.Chord B3 D4>
# <music21.chord.Chord B3 D4>
# <music21.chord.Chord B3 D4>
# <music21.chord.Chord B3 D4>
# <music21.chord.Chord B-3 D4>
# <music21.note.Note D>
# <music21.chord.Chord B-3 D4>
# <music21.chord.Chord B-3 D4>
# <music21.chord.Chord B-3 D4>
# <music21.chord.Chord B-3 D4>
# <music21.chord.Chord B-3 D4>
# <music21.chord.Chord A3 D4>
# <music21.note.Note D>
# <music21.chord.Chord A3 D4>
# <music21.chord.Chord A3 D4>
# <music21.chord.Chord A3 D4>
# <music21.chord.Chord A3 D4>
# <music21.chord.Chord A3 D4>
# <music21.chord.Chord A3 C4 D4>
# <music21.note.Note D>
# <music21.chord.Chord A3 C4 D4>
# <music21.chord.Chord A3 C4 D4>
# <music21.chord.Chord A3 C4 D4>
# <music21.chord.Chord A3 C4 D4>
# <music21.chord.Chord A3 C4 D4>
# <music21.chord.Chord G3 B3 D4>
# <music21.note.Note D>
# <music21.chord.Chord G3 B3 D4>
# <music21.chord.Chord G3 B3 D4>
# <music21.chord.Chord G3 B3 D4>
# <music21.chord.Chord G3 B3 D4>
# <music21.chord.Chord G3 B3 D4>
# <music21.chord.Chord F3 B-3 D4>
# <music21.note.Note D>
# <music21.chord.Chord F3 B-3 D4>
# <music21.chord.Chord F3 B-3 D4>
# <music21.chord.Chord F3 B-3 D4>
# <music21.chord.Chord F3 B-3 D4>
# <music21.chord.Chord F3 B-3 D4>
# a minor
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.chord.Chord C5 A2>
# <music21.chord.Chord D5 A2>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.chord.Chord E-4 A2>
# <music21.note.Note E->
# <music21.note.Note E->
# <music21.note.Note D>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.chord.Chord C4 A2>
# <music21.chord.Chord F4 A4>
# <music21.note.Note A>
# <music21.note.Note F>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.chord.Chord C5 E5 A2>
# <music21.chord.Chord D5 B5 A2>
# <music21.chord.Chord F5 D6>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.note.Note A>
# <music21.note.Note C>
# <music21.chord.Chord B4 A2>
# <music21.chord.Chord A4 A2>
# <music21.meter.TimeSignature 6/8>
# <music21.chord.Chord D5 B5>
# <music21.note.Note G>
# <music21.chord.Chord E5 C6>
# <music21.chord.Chord D5 B5>
# <music21.chord.Chord C5 A5>
# <music21.chord.Chord B4 G5>
# <music21.chord.Chord C5 A5>
# <music21.chord.Chord B4 G5>
# <music21.chord.Chord F4 D5>
# <music21.meter.TimeSignature 4/4>
# <music21.chord.Chord A4 F5>
# <music21.note.Note G>
# <music21.note.Note D>
# <music21.chord.Chord G4 E5>
# <music21.note.Note E>
# <music21.chord.Chord F4 D5>
# <music21.note.Note F>
# <music21.chord.Chord D4 B4>
# <music21.note.Note G>
# <music21.meter.TimeSignature 5/4>
# <music21.chord.Chord E4 C5 A2>
# <music21.chord.Chord A4 D5 A2>
# <music21.chord.Chord C5 E5 A2>
# <music21.chord.Chord D5 F#5 A2>
# <music21.chord.Chord C5 E5 A2>
# <music21.chord.Chord D5 F#5 A2>
# <music21.chord.Chord E5 G5 A2>
# <music21.chord.Chord F#5 A5 A2>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.chord.Chord C5 A2>
# <music21.chord.Chord D5 A2>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.chord.Chord E-4 A2>
# <music21.note.Note E->
# <music21.note.Note E->
# <music21.note.Note D>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.chord.Chord C4 A2>
# <music21.chord.Chord F4 A4>
# <music21.note.Note A>
# <music21.note.Note F>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.chord.Chord C5 E5 A2>
# <music21.chord.Chord D5 B5 A2>
# <music21.chord.Chord F5 D6>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note G>
# <music21.note.Note B->
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note G>
# <music21.note.Note G>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.note.Note F#>
# <music21.note.Note G>
# <music21.note.Note D>
# <music21.note.Note G>
# <music21.note.Note F#>
# <music21.note.Note G>
# <music21.note.Note A>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note G>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note G>
# <music21.note.Note B>
# <music21.chord.Chord E5 C6 A2>
# <music21.chord.Chord A4 D5 A2>
# <music21.chord.Chord C5 E5 A2>
# <music21.chord.Chord D5 F#5 A2>
# <music21.chord.Chord C5 E5 A2>
# <music21.chord.Chord D5 F#5 A2>
# <music21.chord.Chord E5 G5 A2>
# <music21.chord.Chord F#5 A5 A2>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord E4 A2>
# <music21.chord.Chord D4 A2>
# <music21.note.Note E>
# <music21.note.Note G>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord G4 A2>
# <music21.chord.Chord F#4 D3>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.note.Note F>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord E4 A2>
# <music21.chord.Chord F4 A2>
# <music21.chord.Chord E4 E3>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord A3 G3>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord A4 A2>
# <music21.chord.Chord G4 G2>
# <music21.chord.Chord A4 F#3>
# <music21.note.Note D>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord C4 A2>
# <music21.chord.Chord B3 A2>
# <music21.chord.Chord C4 A4>
# <music21.note.Note F>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord E5 A2>
# <music21.chord.Chord D5 A2>
# <music21.note.Note E>
# <music21.note.Note G>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord G5 A2>
# <music21.chord.Chord F#5 D3>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.note.Note F>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord F5 A2>
# <music21.chord.Chord G5 A2>
# <music21.chord.Chord D5 A3 D4>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.chord.Chord F5 A3 C4>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.chord.Chord B4 G5 G3 B3>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.chord.Chord B-4 F5 B-3 D4>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord E4 A2>
# <music21.chord.Chord D4 A2>
# <music21.note.Note E>
# <music21.note.Note G>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord G4 A2>
# <music21.chord.Chord F#4 D3>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.note.Note F>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord C4 A2>
# <music21.chord.Chord B3 A2>
# <music21.chord.Chord C5 F3>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.chord.Chord D5 F3>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.chord.Chord E5 F3>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.chord.Chord F5 F3>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.chord.Chord C5 A2>
# <music21.chord.Chord D5 A2>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.chord.Chord E-4 A2>
# <music21.note.Note E->
# <music21.note.Note E->
# <music21.note.Note D>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.chord.Chord C4 A2>
# <music21.chord.Chord F4 A4>
# <music21.note.Note A>
# <music21.note.Note F>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.chord.Chord C5 E5 A2>
# <music21.chord.Chord D5 B5 A2>
# <music21.chord.Chord F5 D6>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.note.Note A>
# <music21.note.Note C>
# <music21.chord.Chord B4 A2>
# <music21.chord.Chord A4 A2>
# <music21.meter.TimeSignature 6/8>
# <music21.chord.Chord D5 B5>
# <music21.note.Note G>
# <music21.chord.Chord E5 C6>
# <music21.chord.Chord D5 B5>
# <music21.chord.Chord C5 A5>
# <music21.chord.Chord B4 G5>
# <music21.chord.Chord C5 A5>
# <music21.chord.Chord B4 G5>
# <music21.chord.Chord F4 D5>
# <music21.meter.TimeSignature 4/4>
# <music21.chord.Chord A4 F5>
# <music21.note.Note G>
# <music21.note.Note D>
# <music21.chord.Chord G4 E5>
# <music21.note.Note E>
# <music21.chord.Chord F4 D5>
# <music21.note.Note F>
# <music21.chord.Chord D4 B4>
# <music21.note.Note G>
# <music21.meter.TimeSignature 5/4>
# <music21.chord.Chord E4 C5 A2>
# <music21.chord.Chord A4 D5 A2>
# <music21.chord.Chord C5 E5 A2>
# <music21.chord.Chord D5 F#5 A2>
# <music21.chord.Chord C5 E5 A2>
# <music21.chord.Chord D5 F#5 A2>
# <music21.chord.Chord E5 G5 A2>
# <music21.chord.Chord F#5 A5 A2>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.chord.Chord C5 A2>
# <music21.chord.Chord D5 A2>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.chord.Chord E-4 A2>
# <music21.note.Note E->
# <music21.note.Note E->
# <music21.note.Note D>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.chord.Chord C4 A2>
# <music21.chord.Chord F4 A4>
# <music21.note.Note A>
# <music21.note.Note F>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.chord.Chord C5 E5 A2>
# <music21.chord.Chord D5 B5 A2>
# <music21.chord.Chord F5 D6>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note G>
# <music21.note.Note B->
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note G>
# <music21.note.Note G>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.note.Note F#>
# <music21.note.Note G>
# <music21.note.Note D>
# <music21.note.Note G>
# <music21.note.Note F#>
# <music21.note.Note G>
# <music21.note.Note A>
# <music21.note.Note C>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note B>
# <music21.note.Note G>
# <music21.note.Note C>
# <music21.note.Note D>
# <music21.note.Note G>
# <music21.note.Note B>
# <music21.chord.Chord E5 C6 A2>
# <music21.chord.Chord A4 D5 A2>
# <music21.chord.Chord C5 E5 A2>
# <music21.chord.Chord D5 F#5 A2>
# <music21.chord.Chord C5 E5 A2>
# <music21.chord.Chord D5 F#5 A2>
# <music21.chord.Chord E5 G5 A2>
# <music21.chord.Chord F#5 A5 A2>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord E4 A2>
# <music21.chord.Chord D4 A2>
# <music21.note.Note E>
# <music21.note.Note G>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord G4 A2>
# <music21.chord.Chord F#4 D3>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.note.Note F>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord E4 A2>
# <music21.chord.Chord F4 A2>
# <music21.chord.Chord E4 E3>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord A3 G3>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord A4 A2>
# <music21.chord.Chord G4 G2>
# <music21.chord.Chord A4 F#3>
# <music21.note.Note D>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord C4 A2>
# <music21.chord.Chord B3 A2>
# <music21.chord.Chord C4 A4>
# <music21.note.Note F>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord E5 A2>
# <music21.chord.Chord D5 A2>
# <music21.note.Note E>
# <music21.note.Note G>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord G5 A2>
# <music21.chord.Chord F#5 D3>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.note.Note F>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord F5 A2>
# <music21.chord.Chord G5 A2>
# <music21.chord.Chord D5 A3 D4>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.chord.Chord F5 A3 C4>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.chord.Chord B4 G5 G3 B3>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.chord.Chord B-4 F5 B-3 D4>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note D>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord E4 A2>
# <music21.chord.Chord D4 A2>
# <music21.note.Note E>
# <music21.note.Note G>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord G4 A2>
# <music21.chord.Chord F#4 D3>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.note.Note F>
# <music21.note.Note A>
# <music21.note.Note A>
# <music21.chord.Chord C4 A2>
# <music21.chord.Chord B3 A2>
# <music21.chord.Chord C5 F3>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.chord.Chord D5 F3>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.chord.Chord E5 F3>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.chord.Chord F5 F3>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note F>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note A>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.chord.Chord C5 A2>
# <music21.chord.Chord D5 A2>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note A>
# <music21.note.Note E>
# <music21.note.Note E>
# <music21.chord.Chord E-4 A2>
# <music21.note.Note E->
# <music21.note.Note E->
# <music21.note.Note D>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.chord.Chord C4 A2>
# <music21.chord.Chord F4 A4>
# <music21.note.Note A>
# <music21.note.Note F>
# <music21.note.Note B>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.chord.Chord C5 E5 A2>
# <music21.chord.Chord D5 B5 A2>
# <music21.chord.Chord F5 D6>
# <music21.note.Note A>
# <music21.note.Note D>
# <music21.note.Note A>
# <music21.note.Note C>
# <music21.chord.Chord B4 A2>
# <music21.chord.Chord A4 A2>

# %%
midi.flat.notes.show('text')
# Out:
# {0.0} <music21.chord.Chord A3 D4>
# {0.0} <music21.note.Note D>
# {1.0} <music21.chord.Chord A3 D4>
# {1.5} <music21.chord.Chord A3 D4>
# {2.5} <music21.chord.Chord A3 D4>
# {3.0} <music21.chord.Chord A3 D4>
# {4.0} <music21.chord.Chord A3 D4>
# {5.0} <music21.chord.Chord A3 C4 D4>
# {5.0} <music21.note.Note D>
# {6.0} <music21.chord.Chord A3 C4 D4>
# {6.5} <music21.chord.Chord A3 C4 D4>
# {7.5} <music21.chord.Chord A3 C4 D4>
# {8.0} <music21.chord.Chord A3 C4 D4>
# {9.0} <music21.chord.Chord A3 C4 D4>
# {10.0} <music21.chord.Chord B3 D4>
# {10.0} <music21.note.Note D>
# {11.0} <music21.chord.Chord B3 D4>
# {11.5} <music21.chord.Chord B3 D4>
# {12.5} <music21.chord.Chord B3 D4>
# {13.0} <music21.chord.Chord B3 D4>
# {14.0} <music21.chord.Chord B3 D4>
# {15.0} <music21.chord.Chord B-3 D4>
# {15.0} <music21.note.Note D>
# {16.0} <music21.chord.Chord B-3 D4>
# {16.5} <music21.chord.Chord B-3 D4>
# {17.5} <music21.chord.Chord B-3 D4>
# {18.0} <music21.chord.Chord B-3 D4>
# {19.0} <music21.chord.Chord B-3 D4>
# {20.0} <music21.chord.Chord A3 D4>
# {20.0} <music21.note.Note D>
# {21.0} <music21.chord.Chord A3 D4>
# {21.5} <music21.chord.Chord A3 D4>
# {22.5} <music21.chord.Chord A3 D4>
# {23.0} <music21.chord.Chord A3 D4>
# {24.0} <music21.chord.Chord A3 D4>
# {25.0} <music21.chord.Chord A3 C4 D4>
# {25.0} <music21.note.Note D>
# {26.0} <music21.chord.Chord A3 C4 D4>
# {26.5} <music21.chord.Chord A3 C4 D4>
# {27.5} <music21.chord.Chord A3 C4 D4>
# {28.0} <music21.chord.Chord A3 C4 D4>
# {29.0} <music21.chord.Chord A3 C4 D4>
# {30.0} <music21.chord.Chord G3 B3 D4>
# {30.0} <music21.note.Note D>
# {31.0} <music21.chord.Chord G3 B3 D4>
# {31.5} <music21.chord.Chord G3 B3 D4>
# {32.5} <music21.chord.Chord G3 B3 D4>
# {33.0} <music21.chord.Chord G3 B3 D4>
# {34.0} <music21.chord.Chord G3 B3 D4>
# {35.0} <music21.chord.Chord F3 B-3 D4>
# {35.0} <music21.note.Note D>
# {36.0} <music21.chord.Chord F3 B-3 D4>
# {36.5} <music21.chord.Chord F3 B-3 D4>
# {37.5} <music21.chord.Chord F3 B-3 D4>
# {38.0} <music21.chord.Chord F3 B-3 D4>
# {39.0} <music21.chord.Chord F3 B-3 D4>
# {40.0} <music21.note.Note A>
# {40.0} <music21.note.Note E>
# {40.0} <music21.note.Note A>
# {41.5} <music21.note.Note B>
# {41.5} <music21.note.Note A>
# {43.0} <music21.chord.Chord C5 A2>
# {44.0} <music21.chord.Chord D5 A2>
# {45.0} <music21.note.Note A>
# {45.0} <music21.note.Note E>
# {45.0} <music21.note.Note A>
# {45.5} <music21.note.Note E>
# {46.0} <music21.note.Note E>
# {46.5} <music21.chord.Chord E-4 A2>
# {47.0} <music21.note.Note E->
# {47.5} <music21.note.Note E->
# {48.0} <music21.note.Note D>
# {48.0} <music21.note.Note A>
# {48.5} <music21.note.Note D>
# {49.0} <music21.chord.Chord C4 A2>
# {50.0} <music21.chord.Chord F4 A4>
# {50.0} <music21.note.Note A>
# {51.5} <music21.note.Note F>
# {51.5} <music21.note.Note B>
# {51.5} <music21.note.Note A>
# {52.5} <music21.note.Note D>
# {53.0} <music21.chord.Chord C5 E5 A2>
# {54.0} <music21.chord.Chord D5 B5 A2>
# {55.0} <music21.chord.Chord F5 D6>
# {55.0} <music21.note.Note A>
# {56.0} <music21.note.Note D>
# {56.5} <music21.note.Note A>
# {57.0} <music21.note.Note C>
# {58.0} <music21.chord.Chord B4 A2>
# {59.0} <music21.chord.Chord A4 A2>
# {60.0} <music21.chord.Chord D5 B5>
# {60.0} <music21.note.Note G>
# {61.0} <music21.chord.Chord E5 C6>
# {61.5} <music21.chord.Chord D5 B5>
# {62.5} <music21.chord.Chord C5 A5>
# {63.0} <music21.chord.Chord B4 G5>
# {64.0} <music21.chord.Chord C5 A5>
# {64.5} <music21.chord.Chord B4 G5>
# {65.5} <music21.chord.Chord F4 D5>
# {66.0} <music21.chord.Chord A4 F5>
# {66.0} <music21.note.Note G>
# {66.5} <music21.note.Note D>
# {67.0} <music21.chord.Chord G4 E5>
# {67.5} <music21.note.Note E>
# {68.0} <music21.chord.Chord F4 D5>
# {68.5} <music21.note.Note F>
# {69.0} <music21.chord.Chord D4 B4>
# {69.5} <music21.note.Note G>
# {70.0} <music21.chord.Chord E4 C5 A2>
# {71.5} <music21.chord.Chord A4 D5 A2>
# {73.0} <music21.chord.Chord C5 E5 A2>
# {74.0} <music21.chord.Chord D5 F#5 A2>
# {75.0} <music21.chord.Chord C5 E5 A2>
# {76.5} <music21.chord.Chord D5 F#5 A2>
# {78.0} <music21.chord.Chord E5 G5 A2>
# {79.0} <music21.chord.Chord F#5 A5 A2>
# {80.0} <music21.note.Note A>
# {80.0} <music21.note.Note E>
# {80.0} <music21.note.Note A>
# {81.5} <music21.note.Note B>
# {81.5} <music21.note.Note A>
# {83.0} <music21.chord.Chord C5 A2>
# {84.0} <music21.chord.Chord D5 A2>
# {85.0} <music21.note.Note A>
# {85.0} <music21.note.Note E>
# {85.0} <music21.note.Note A>
# {85.5} <music21.note.Note E>
# {86.0} <music21.note.Note E>
# {86.5} <music21.chord.Chord E-4 A2>
# {87.0} <music21.note.Note E->
# {87.5} <music21.note.Note E->
# {88.0} <music21.note.Note D>
# {88.0} <music21.note.Note A>
# {88.5} <music21.note.Note D>
# {89.0} <music21.chord.Chord C4 A2>
# {90.0} <music21.chord.Chord F4 A4>
# {90.0} <music21.note.Note A>
# {91.5} <music21.note.Note F>
# {91.5} <music21.note.Note B>
# {91.5} <music21.note.Note A>
# {92.5} <music21.note.Note D>
# {93.0} <music21.chord.Chord C5 E5 A2>
# {94.0} <music21.chord.Chord D5 B5 A2>
# {95.0} <music21.chord.Chord F5 D6>
# {95.0} <music21.note.Note A>
# {96.5} <music21.note.Note A>
# {97.5} <music21.note.Note A>
# {98.0} <music21.note.Note A>
# {99.0} <music21.note.Note E>
# {100.0} <music21.note.Note B>
# {100.0} <music21.note.Note B>
# {100.0} <music21.note.Note G>
# {100.5} <music21.note.Note B->
# {101.0} <music21.note.Note B>
# {101.5} <music21.note.Note C>
# {101.5} <music21.note.Note A>
# {102.0} <music21.note.Note B>
# {102.5} <music21.note.Note C>
# {103.0} <music21.note.Note D>
# {103.0} <music21.note.Note G>
# {103.5} <music21.note.Note G>
# {104.0} <music21.note.Note A>
# {104.0} <music21.note.Note D>
# {104.5} <music21.note.Note F#>
# {105.0} <music21.note.Note G>
# {105.0} <music21.note.Note D>
# {105.0} <music21.note.Note G>
# {105.5} <music21.note.Note F#>
# {106.0} <music21.note.Note G>
# {106.5} <music21.note.Note A>
# {106.5} <music21.note.Note C>
# {107.0} <music21.note.Note B>
# {107.5} <music21.note.Note A>
# {108.0} <music21.note.Note B>
# {108.0} <music21.note.Note B>
# {108.0} <music21.note.Note G>
# {108.5} <music21.note.Note C>
# {109.0} <music21.note.Note D>
# {109.0} <music21.note.Note G>
# {109.5} <music21.note.Note B>
# {110.0} <music21.chord.Chord E5 C6 A2>
# {111.5} <music21.chord.Chord A4 D5 A2>
# {113.0} <music21.chord.Chord C5 E5 A2>
# {114.0} <music21.chord.Chord D5 F#5 A2>
# {115.0} <music21.chord.Chord C5 E5 A2>
# {116.5} <music21.chord.Chord D5 F#5 A2>
# {118.0} <music21.chord.Chord E5 G5 A2>
# {119.0} <music21.chord.Chord F#5 A5 A2>
# {120.0} <music21.note.Note A>
# {120.0} <music21.note.Note E>
# {120.0} <music21.note.Note A>
# {121.5} <music21.note.Note A>
# {123.0} <music21.chord.Chord E4 A2>
# {124.0} <music21.chord.Chord D4 A2>
# {125.0} <music21.note.Note E>
# {125.0} <music21.note.Note G>
# {125.0} <music21.note.Note A>
# {126.5} <music21.note.Note A>
# {128.0} <music21.note.Note A>
# {129.0} <music21.chord.Chord G4 A2>
# {130.0} <music21.chord.Chord F#4 D3>
# {130.0} <music21.note.Note A>
# {131.5} <music21.note.Note A>
# {133.0} <music21.note.Note A>
# {134.0} <music21.note.Note A>
# {135.0} <music21.note.Note D>
# {135.0} <music21.note.Note F>
# {135.0} <music21.note.Note A>
# {136.5} <music21.note.Note A>
# {138.0} <music21.chord.Chord E4 A2>
# {139.0} <music21.chord.Chord F4 A2>
# {140.0} <music21.chord.Chord E4 E3>
# {140.0} <music21.note.Note A>
# {141.5} <music21.note.Note A>
# {143.0} <music21.note.Note A>
# {144.0} <music21.note.Note A>
# {145.0} <music21.chord.Chord A3 G3>
# {145.0} <music21.note.Note A>
# {146.5} <music21.note.Note A>
# {148.0} <music21.chord.Chord A4 A2>
# {149.0} <music21.chord.Chord G4 G2>
# {150.0} <music21.chord.Chord A4 F#3>
# {150.0} <music21.note.Note D>
# {150.0} <music21.note.Note A>
# {151.5} <music21.note.Note A>
# {153.0} <music21.chord.Chord C4 A2>
# {154.0} <music21.chord.Chord B3 A2>
# {155.0} <music21.chord.Chord C4 A4>
# {155.0} <music21.note.Note F>
# {155.0} <music21.note.Note A>
# {156.5} <music21.note.Note A>
# {158.0} <music21.note.Note A>
# {159.0} <music21.note.Note A>
# {160.0} <music21.note.Note A>
# {160.0} <music21.note.Note E>
# {160.0} <music21.note.Note A>
# {161.5} <music21.note.Note A>
# {163.0} <music21.chord.Chord E5 A2>
# {164.0} <music21.chord.Chord D5 A2>
# {165.0} <music21.note.Note E>
# {165.0} <music21.note.Note G>
# {165.0} <music21.note.Note A>
# {166.5} <music21.note.Note A>
# {168.0} <music21.note.Note A>
# {169.0} <music21.chord.Chord G5 A2>
# {170.0} <music21.chord.Chord F#5 D3>
# {170.0} <music21.note.Note A>
# {171.5} <music21.note.Note A>
# {173.0} <music21.note.Note A>
# {174.0} <music21.note.Note A>
# {175.0} <music21.note.Note D>
# {175.0} <music21.note.Note F>
# {175.0} <music21.note.Note A>
# {176.5} <music21.note.Note A>
# {178.0} <music21.chord.Chord F5 A2>
# {179.0} <music21.chord.Chord G5 A2>
# {180.0} <music21.chord.Chord D5 A3 D4>
# {180.0} <music21.note.Note A>
# {180.0} <music21.note.Note D>
# {181.5} <music21.note.Note D>
# {183.0} <music21.note.Note D>
# {184.0} <music21.note.Note D>
# {185.0} <music21.chord.Chord F5 A3 C4>
# {185.0} <music21.note.Note D>
# {186.5} <music21.note.Note D>
# {188.0} <music21.note.Note D>
# {189.0} <music21.note.Note D>
# {190.0} <music21.chord.Chord B4 G5 G3 B3>
# {190.0} <music21.note.Note D>
# {191.5} <music21.note.Note D>
# {193.0} <music21.note.Note D>
# {194.0} <music21.note.Note D>
# {195.0} <music21.chord.Chord B-4 F5 B-3 D4>
# {195.0} <music21.note.Note D>
# {196.5} <music21.note.Note D>
# {198.0} <music21.note.Note D>
# {199.0} <music21.note.Note D>
# {200.0} <music21.note.Note A>
# {200.0} <music21.note.Note E>
# {200.0} <music21.note.Note A>
# {201.5} <music21.note.Note A>
# {203.0} <music21.chord.Chord E4 A2>
# {204.0} <music21.chord.Chord D4 A2>
# {205.0} <music21.note.Note E>
# {205.0} <music21.note.Note G>
# {205.0} <music21.note.Note A>
# {206.5} <music21.note.Note A>
# {208.0} <music21.note.Note A>
# {209.0} <music21.chord.Chord G4 A2>
# {210.0} <music21.chord.Chord F#4 D3>
# {210.0} <music21.note.Note A>
# {211.5} <music21.note.Note A>
# {213.0} <music21.note.Note A>
# {214.0} <music21.note.Note A>
# {215.0} <music21.note.Note D>
# {215.0} <music21.note.Note F>
# {215.0} <music21.note.Note A>
# {216.5} <music21.note.Note A>
# {218.0} <music21.chord.Chord C4 A2>
# {219.0} <music21.chord.Chord B3 A2>
# {220.0} <music21.chord.Chord C5 F3>
# {220.0} <music21.note.Note F>
# {221.5} <music21.note.Note F>
# {223.0} <music21.note.Note F>
# {224.0} <music21.note.Note F>
# {225.0} <music21.chord.Chord D5 F3>
# {225.0} <music21.note.Note F>
# {226.5} <music21.note.Note F>
# {228.0} <music21.note.Note F>
# {229.0} <music21.note.Note F>
# {230.0} <music21.chord.Chord E5 F3>
# {230.0} <music21.note.Note F>
# {231.5} <music21.note.Note F>
# {233.0} <music21.note.Note F>
# {234.0} <music21.note.Note F>
# {235.0} <music21.chord.Chord F5 F3>
# {235.0} <music21.note.Note F>
# {236.5} <music21.note.Note F>
# {238.0} <music21.note.Note F>
# {239.0} <music21.note.Note F>
# {240.0} <music21.note.Note A>
# {240.0} <music21.note.Note E>
# {240.0} <music21.note.Note A>
# {241.5} <music21.note.Note B>
# {241.5} <music21.note.Note A>
# {243.0} <music21.chord.Chord C5 A2>
# {244.0} <music21.chord.Chord D5 A2>
# {245.0} <music21.note.Note A>
# {245.0} <music21.note.Note E>
# {245.0} <music21.note.Note A>
# {245.5} <music21.note.Note E>
# {246.0} <music21.note.Note E>
# {246.5} <music21.chord.Chord E-4 A2>
# {247.0} <music21.note.Note E->
# {247.5} <music21.note.Note E->
# {248.0} <music21.note.Note D>
# {248.0} <music21.note.Note A>
# {248.5} <music21.note.Note D>
# {249.0} <music21.chord.Chord C4 A2>
# {250.0} <music21.chord.Chord F4 A4>
# {250.0} <music21.note.Note A>
# {251.5} <music21.note.Note F>
# {251.5} <music21.note.Note B>
# {251.5} <music21.note.Note A>
# {252.5} <music21.note.Note D>
# {253.0} <music21.chord.Chord C5 E5 A2>
# {254.0} <music21.chord.Chord D5 B5 A2>
# {255.0} <music21.chord.Chord F5 D6>
# {255.0} <music21.note.Note A>
# {256.0} <music21.note.Note D>
# {256.5} <music21.note.Note A>
# {257.0} <music21.note.Note C>
# {258.0} <music21.chord.Chord B4 A2>
# {259.0} <music21.chord.Chord A4 A2>
# {260.0} <music21.chord.Chord D5 B5>
# {260.0} <music21.note.Note G>
# {261.0} <music21.chord.Chord E5 C6>
# {261.5} <music21.chord.Chord D5 B5>
# {262.5} <music21.chord.Chord C5 A5>
# {263.0} <music21.chord.Chord B4 G5>
# {264.0} <music21.chord.Chord C5 A5>
# {264.5} <music21.chord.Chord B4 G5>
# {265.5} <music21.chord.Chord F4 D5>
# {266.0} <music21.chord.Chord A4 F5>
# {266.0} <music21.note.Note G>
# {266.5} <music21.note.Note D>
# {267.0} <music21.chord.Chord G4 E5>
# {267.5} <music21.note.Note E>
# {268.0} <music21.chord.Chord F4 D5>
# {268.5} <music21.note.Note F>
# {269.0} <music21.chord.Chord D4 B4>
# {269.5} <music21.note.Note G>
# {270.0} <music21.chord.Chord E4 C5 A2>
# {271.5} <music21.chord.Chord A4 D5 A2>
# {273.0} <music21.chord.Chord C5 E5 A2>
# {274.0} <music21.chord.Chord D5 F#5 A2>
# {275.0} <music21.chord.Chord C5 E5 A2>
# {276.5} <music21.chord.Chord D5 F#5 A2>
# {278.0} <music21.chord.Chord E5 G5 A2>
# {279.0} <music21.chord.Chord F#5 A5 A2>
# {280.0} <music21.note.Note A>
# {280.0} <music21.note.Note E>
# {280.0} <music21.note.Note A>
# {281.5} <music21.note.Note B>
# {281.5} <music21.note.Note A>
# {283.0} <music21.chord.Chord C5 A2>
# {284.0} <music21.chord.Chord D5 A2>
# {285.0} <music21.note.Note A>
# {285.0} <music21.note.Note E>
# {285.0} <music21.note.Note A>
# {285.5} <music21.note.Note E>
# {286.0} <music21.note.Note E>
# {286.5} <music21.chord.Chord E-4 A2>
# {287.0} <music21.note.Note E->
# {287.5} <music21.note.Note E->
# {288.0} <music21.note.Note D>
# {288.0} <music21.note.Note A>
# {288.5} <music21.note.Note D>
# {289.0} <music21.chord.Chord C4 A2>
# {290.0} <music21.chord.Chord F4 A4>
# {290.0} <music21.note.Note A>
# {291.5} <music21.note.Note F>
# {291.5} <music21.note.Note B>
# {291.5} <music21.note.Note A>
# {292.5} <music21.note.Note D>
# {293.0} <music21.chord.Chord C5 E5 A2>
# {294.0} <music21.chord.Chord D5 B5 A2>
# {295.0} <music21.chord.Chord F5 D6>
# {295.0} <music21.note.Note A>
# {296.5} <music21.note.Note A>
# {297.5} <music21.note.Note A>
# {298.0} <music21.note.Note A>
# {299.0} <music21.note.Note E>
# {300.0} <music21.note.Note B>
# {300.0} <music21.note.Note B>
# {300.0} <music21.note.Note G>
# {300.5} <music21.note.Note B->
# {301.0} <music21.note.Note B>
# {301.5} <music21.note.Note C>
# {301.5} <music21.note.Note A>
# {302.0} <music21.note.Note B>
# {302.5} <music21.note.Note C>
# {303.0} <music21.note.Note D>
# {303.0} <music21.note.Note G>
# {303.5} <music21.note.Note G>
# {304.0} <music21.note.Note A>
# {304.0} <music21.note.Note D>
# {304.5} <music21.note.Note F#>
# {305.0} <music21.note.Note G>
# {305.0} <music21.note.Note D>
# {305.0} <music21.note.Note G>
# {305.5} <music21.note.Note F#>
# {306.0} <music21.note.Note G>
# {306.5} <music21.note.Note A>
# {306.5} <music21.note.Note C>
# {307.0} <music21.note.Note B>
# {307.5} <music21.note.Note A>
# {308.0} <music21.note.Note B>
# {308.0} <music21.note.Note B>
# {308.0} <music21.note.Note G>
# {308.5} <music21.note.Note C>
# {309.0} <music21.note.Note D>
# {309.0} <music21.note.Note G>
# {309.5} <music21.note.Note B>
# {310.0} <music21.chord.Chord E5 C6 A2>
# {311.5} <music21.chord.Chord A4 D5 A2>
# {313.0} <music21.chord.Chord C5 E5 A2>
# {314.0} <music21.chord.Chord D5 F#5 A2>
# {315.0} <music21.chord.Chord C5 E5 A2>
# {316.5} <music21.chord.Chord D5 F#5 A2>
# {318.0} <music21.chord.Chord E5 G5 A2>
# {319.0} <music21.chord.Chord F#5 A5 A2>
# {320.0} <music21.note.Note A>
# {320.0} <music21.note.Note E>
# {320.0} <music21.note.Note A>
# {321.5} <music21.note.Note A>
# {323.0} <music21.chord.Chord E4 A2>
# {324.0} <music21.chord.Chord D4 A2>
# {325.0} <music21.note.Note E>
# {325.0} <music21.note.Note G>
# {325.0} <music21.note.Note A>
# {326.5} <music21.note.Note A>
# {328.0} <music21.note.Note A>
# {329.0} <music21.chord.Chord G4 A2>
# {330.0} <music21.chord.Chord F#4 D3>
# {330.0} <music21.note.Note A>
# {331.5} <music21.note.Note A>
# {333.0} <music21.note.Note A>
# {334.0} <music21.note.Note A>
# {335.0} <music21.note.Note D>
# {335.0} <music21.note.Note F>
# {335.0} <music21.note.Note A>
# {336.5} <music21.note.Note A>
# {338.0} <music21.chord.Chord E4 A2>
# {339.0} <music21.chord.Chord F4 A2>
# {340.0} <music21.chord.Chord E4 E3>
# {340.0} <music21.note.Note A>
# {341.5} <music21.note.Note A>
# {343.0} <music21.note.Note A>
# {344.0} <music21.note.Note A>
# {345.0} <music21.chord.Chord A3 G3>
# {345.0} <music21.note.Note A>
# {346.5} <music21.note.Note A>
# {348.0} <music21.chord.Chord A4 A2>
# {349.0} <music21.chord.Chord G4 G2>
# {350.0} <music21.chord.Chord A4 F#3>
# {350.0} <music21.note.Note D>
# {350.0} <music21.note.Note A>
# {351.5} <music21.note.Note A>
# {353.0} <music21.chord.Chord C4 A2>
# {354.0} <music21.chord.Chord B3 A2>
# {355.0} <music21.chord.Chord C4 A4>
# {355.0} <music21.note.Note F>
# {355.0} <music21.note.Note A>
# {356.5} <music21.note.Note A>
# {358.0} <music21.note.Note A>
# {359.0} <music21.note.Note A>
# {360.0} <music21.note.Note A>
# {360.0} <music21.note.Note E>
# {360.0} <music21.note.Note A>
# {361.5} <music21.note.Note A>
# {363.0} <music21.chord.Chord E5 A2>
# {364.0} <music21.chord.Chord D5 A2>
# {365.0} <music21.note.Note E>
# {365.0} <music21.note.Note G>
# {365.0} <music21.note.Note A>
# {366.5} <music21.note.Note A>
# {368.0} <music21.note.Note A>
# {369.0} <music21.chord.Chord G5 A2>
# {370.0} <music21.chord.Chord F#5 D3>
# {370.0} <music21.note.Note A>
# {371.5} <music21.note.Note A>
# {373.0} <music21.note.Note A>
# {374.0} <music21.note.Note A>
# {375.0} <music21.note.Note D>
# {375.0} <music21.note.Note F>
# {375.0} <music21.note.Note A>
# {376.5} <music21.note.Note A>
# {378.0} <music21.chord.Chord F5 A2>
# {379.0} <music21.chord.Chord G5 A2>
# {380.0} <music21.chord.Chord D5 A3 D4>
# {380.0} <music21.note.Note A>
# {380.0} <music21.note.Note D>
# {381.5} <music21.note.Note D>
# {383.0} <music21.note.Note D>
# {384.0} <music21.note.Note D>
# {385.0} <music21.chord.Chord F5 A3 C4>
# {385.0} <music21.note.Note D>
# {386.5} <music21.note.Note D>
# {388.0} <music21.note.Note D>
# {389.0} <music21.note.Note D>
# {390.0} <music21.chord.Chord B4 G5 G3 B3>
# {390.0} <music21.note.Note D>
# {391.5} <music21.note.Note D>
# {393.0} <music21.note.Note D>
# {394.0} <music21.note.Note D>
# {395.0} <music21.chord.Chord B-4 F5 B-3 D4>
# {395.0} <music21.note.Note D>
# {396.5} <music21.note.Note D>
# {398.0} <music21.note.Note D>
# {399.0} <music21.note.Note D>
# {400.0} <music21.note.Note A>
# {400.0} <music21.note.Note E>
# {400.0} <music21.note.Note A>
# {401.5} <music21.note.Note A>
# {403.0} <music21.chord.Chord E4 A2>
# {404.0} <music21.chord.Chord D4 A2>
# {405.0} <music21.note.Note E>
# {405.0} <music21.note.Note G>
# {405.0} <music21.note.Note A>
# {406.5} <music21.note.Note A>
# {408.0} <music21.note.Note A>
# {409.0} <music21.chord.Chord G4 A2>
# {410.0} <music21.chord.Chord F#4 D3>
# {410.0} <music21.note.Note A>
# {411.5} <music21.note.Note A>
# {413.0} <music21.note.Note A>
# {414.0} <music21.note.Note A>
# {415.0} <music21.note.Note D>
# {415.0} <music21.note.Note F>
# {415.0} <music21.note.Note A>
# {416.5} <music21.note.Note A>
# {418.0} <music21.chord.Chord C4 A2>
# {419.0} <music21.chord.Chord B3 A2>
# {420.0} <music21.chord.Chord C5 F3>
# {420.0} <music21.note.Note F>
# {421.5} <music21.note.Note F>
# {423.0} <music21.note.Note F>
# {424.0} <music21.note.Note F>
# {425.0} <music21.chord.Chord D5 F3>
# {425.0} <music21.note.Note F>
# {426.5} <music21.note.Note F>
# {428.0} <music21.note.Note F>
# {429.0} <music21.note.Note F>
# {430.0} <music21.chord.Chord E5 F3>
# {430.0} <music21.note.Note F>
# {431.5} <music21.note.Note F>
# {433.0} <music21.note.Note F>
# {434.0} <music21.note.Note F>
# {435.0} <music21.chord.Chord F5 F3>
# {435.0} <music21.note.Note F>
# {436.5} <music21.note.Note F>
# {438.0} <music21.note.Note F>
# {439.0} <music21.note.Note F>
# {440.0} <music21.note.Note A>
# {440.0} <music21.note.Note E>
# {440.0} <music21.note.Note A>
# {441.5} <music21.note.Note B>
# {441.5} <music21.note.Note A>
# {443.0} <music21.chord.Chord C5 A2>
# {444.0} <music21.chord.Chord D5 A2>
# {445.0} <music21.note.Note A>
# {445.0} <music21.note.Note E>
# {445.0} <music21.note.Note A>
# {445.5} <music21.note.Note E>
# {446.0} <music21.note.Note E>
# {446.5} <music21.chord.Chord E-4 A2>
# {447.0} <music21.note.Note E->
# {447.5} <music21.note.Note E->
# {448.0} <music21.note.Note D>
# {448.0} <music21.note.Note A>
# {448.5} <music21.note.Note D>
# {449.0} <music21.chord.Chord C4 A2>
# {450.0} <music21.chord.Chord F4 A4>
# {450.0} <music21.note.Note A>
# {451.5} <music21.note.Note F>
# {451.5} <music21.note.Note B>
# {451.5} <music21.note.Note A>
# {452.5} <music21.note.Note D>
# {453.0} <music21.chord.Chord C5 E5 A2>
# {454.0} <music21.chord.Chord D5 B5 A2>
# {455.0} <music21.chord.Chord F5 D6>
# {455.0} <music21.note.Note A>
# {456.0} <music21.note.Note D>
# {456.5} <music21.note.Note A>
# {457.0} <music21.note.Note C>
# {458.0} <music21.chord.Chord B4 A2>
# {459.0} <music21.chord.Chord A4 A2>

# %%
len(midi.flat.notes)
# Out:
# 618

# %%
notes_to_parse = midi.flat.notes

# %%
for i in notes_to_parse:
    print(i, i.offset)
# Out:
# <music21.chord.Chord A3 D4> 0.0
# <music21.note.Note D> 0.0
# <music21.chord.Chord A3 D4> 1.0
# <music21.chord.Chord A3 D4> 1.5
# <music21.chord.Chord A3 D4> 2.5
# <music21.chord.Chord A3 D4> 3.0
# <music21.chord.Chord A3 D4> 4.0
# <music21.chord.Chord A3 C4 D4> 5.0
# <music21.note.Note D> 5.0
# <music21.chord.Chord A3 C4 D4> 6.0
# <music21.chord.Chord A3 C4 D4> 6.5
# <music21.chord.Chord A3 C4 D4> 7.5
# <music21.chord.Chord A3 C4 D4> 8.0
# <music21.chord.Chord A3 C4 D4> 9.0
# <music21.chord.Chord B3 D4> 10.0
# <music21.note.Note D> 10.0
# <music21.chord.Chord B3 D4> 11.0
# <music21.chord.Chord B3 D4> 11.5
# <music21.chord.Chord B3 D4> 12.5
# <music21.chord.Chord B3 D4> 13.0
# <music21.chord.Chord B3 D4> 14.0
# <music21.chord.Chord B-3 D4> 15.0
# <music21.note.Note D> 15.0
# <music21.chord.Chord B-3 D4> 16.0
# <music21.chord.Chord B-3 D4> 16.5
# <music21.chord.Chord B-3 D4> 17.5
# <music21.chord.Chord B-3 D4> 18.0
# <music21.chord.Chord B-3 D4> 19.0
# <music21.chord.Chord A3 D4> 20.0
# <music21.note.Note D> 20.0
# <music21.chord.Chord A3 D4> 21.0
# <music21.chord.Chord A3 D4> 21.5
# <music21.chord.Chord A3 D4> 22.5
# <music21.chord.Chord A3 D4> 23.0
# <music21.chord.Chord A3 D4> 24.0
# <music21.chord.Chord A3 C4 D4> 25.0
# <music21.note.Note D> 25.0
# <music21.chord.Chord A3 C4 D4> 26.0
# <music21.chord.Chord A3 C4 D4> 26.5
# <music21.chord.Chord A3 C4 D4> 27.5
# <music21.chord.Chord A3 C4 D4> 28.0
# <music21.chord.Chord A3 C4 D4> 29.0
# <music21.chord.Chord G3 B3 D4> 30.0
# <music21.note.Note D> 30.0
# <music21.chord.Chord G3 B3 D4> 31.0
# <music21.chord.Chord G3 B3 D4> 31.5
# <music21.chord.Chord G3 B3 D4> 32.5
# <music21.chord.Chord G3 B3 D4> 33.0
# <music21.chord.Chord G3 B3 D4> 34.0
# <music21.chord.Chord F3 B-3 D4> 35.0
# <music21.note.Note D> 35.0
# <music21.chord.Chord F3 B-3 D4> 36.0
# <music21.chord.Chord F3 B-3 D4> 36.5
# <music21.chord.Chord F3 B-3 D4> 37.5
# <music21.chord.Chord F3 B-3 D4> 38.0
# <music21.chord.Chord F3 B-3 D4> 39.0
# <music21.note.Note A> 40.0
# <music21.note.Note E> 40.0
# <music21.note.Note A> 40.0
# <music21.note.Note B> 41.5
# <music21.note.Note A> 41.5
# <music21.chord.Chord C5 A2> 43.0
# <music21.chord.Chord D5 A2> 44.0
# <music21.note.Note A> 45.0
# <music21.note.Note E> 45.0
# <music21.note.Note A> 45.0
# <music21.note.Note E> 45.5
# <music21.note.Note E> 46.0
# <music21.chord.Chord E-4 A2> 46.5
# <music21.note.Note E-> 47.0
# <music21.note.Note E-> 47.5
# <music21.note.Note D> 48.0
# <music21.note.Note A> 48.0
# <music21.note.Note D> 48.5
# <music21.chord.Chord C4 A2> 49.0
# <music21.chord.Chord F4 A4> 50.0
# <music21.note.Note A> 50.0
# <music21.note.Note F> 51.5
# <music21.note.Note B> 51.5
# <music21.note.Note A> 51.5
# <music21.note.Note D> 52.5
# <music21.chord.Chord C5 E5 A2> 53.0
# <music21.chord.Chord D5 B5 A2> 54.0
# <music21.chord.Chord F5 D6> 55.0
# <music21.note.Note A> 55.0
# <music21.note.Note D> 56.0
# <music21.note.Note A> 56.5
# <music21.note.Note C> 57.0
# <music21.chord.Chord B4 A2> 58.0
# <music21.chord.Chord A4 A2> 59.0
# <music21.chord.Chord D5 B5> 60.0
# <music21.note.Note G> 60.0
# <music21.chord.Chord E5 C6> 61.0
# <music21.chord.Chord D5 B5> 61.5
# <music21.chord.Chord C5 A5> 62.5
# <music21.chord.Chord B4 G5> 63.0
# <music21.chord.Chord C5 A5> 64.0
# <music21.chord.Chord B4 G5> 64.5
# <music21.chord.Chord F4 D5> 65.5
# <music21.chord.Chord A4 F5> 66.0
# <music21.note.Note G> 66.0
# <music21.note.Note D> 66.5
# <music21.chord.Chord G4 E5> 67.0
# <music21.note.Note E> 67.5
# <music21.chord.Chord F4 D5> 68.0
# <music21.note.Note F> 68.5
# <music21.chord.Chord D4 B4> 69.0
# <music21.note.Note G> 69.5
# <music21.chord.Chord E4 C5 A2> 70.0
# <music21.chord.Chord A4 D5 A2> 71.5
# <music21.chord.Chord C5 E5 A2> 73.0
# <music21.chord.Chord D5 F#5 A2> 74.0
# <music21.chord.Chord C5 E5 A2> 75.0
# <music21.chord.Chord D5 F#5 A2> 76.5
# <music21.chord.Chord E5 G5 A2> 78.0
# <music21.chord.Chord F#5 A5 A2> 79.0
# <music21.note.Note A> 80.0
# <music21.note.Note E> 80.0
# <music21.note.Note A> 80.0
# <music21.note.Note B> 81.5
# <music21.note.Note A> 81.5
# <music21.chord.Chord C5 A2> 83.0
# <music21.chord.Chord D5 A2> 84.0
# <music21.note.Note A> 85.0
# <music21.note.Note E> 85.0
# <music21.note.Note A> 85.0
# <music21.note.Note E> 85.5
# <music21.note.Note E> 86.0
# <music21.chord.Chord E-4 A2> 86.5
# <music21.note.Note E-> 87.0
# <music21.note.Note E-> 87.5
# <music21.note.Note D> 88.0
# <music21.note.Note A> 88.0
# <music21.note.Note D> 88.5
# <music21.chord.Chord C4 A2> 89.0
# <music21.chord.Chord F4 A4> 90.0
# <music21.note.Note A> 90.0
# <music21.note.Note F> 91.5
# <music21.note.Note B> 91.5
# <music21.note.Note A> 91.5
# <music21.note.Note D> 92.5
# <music21.chord.Chord C5 E5 A2> 93.0
# <music21.chord.Chord D5 B5 A2> 94.0
# <music21.chord.Chord F5 D6> 95.0
# <music21.note.Note A> 95.0
# <music21.note.Note A> 96.5
# <music21.note.Note A> 97.5
# <music21.note.Note A> 98.0
# <music21.note.Note E> 99.0
# <music21.note.Note B> 100.0
# <music21.note.Note B> 100.0
# <music21.note.Note G> 100.0
# <music21.note.Note B-> 100.5
# <music21.note.Note B> 101.0
# <music21.note.Note C> 101.5
# <music21.note.Note A> 101.5
# <music21.note.Note B> 102.0
# <music21.note.Note C> 102.5
# <music21.note.Note D> 103.0
# <music21.note.Note G> 103.0
# <music21.note.Note G> 103.5
# <music21.note.Note A> 104.0
# <music21.note.Note D> 104.0
# <music21.note.Note F#> 104.5
# <music21.note.Note G> 105.0
# <music21.note.Note D> 105.0
# <music21.note.Note G> 105.0
# <music21.note.Note F#> 105.5
# <music21.note.Note G> 106.0
# <music21.note.Note A> 106.5
# <music21.note.Note C> 106.5
# <music21.note.Note B> 107.0
# <music21.note.Note A> 107.5
# <music21.note.Note B> 108.0
# <music21.note.Note B> 108.0
# <music21.note.Note G> 108.0
# <music21.note.Note C> 108.5
# <music21.note.Note D> 109.0
# <music21.note.Note G> 109.0
# <music21.note.Note B> 109.5
# <music21.chord.Chord E5 C6 A2> 110.0
# <music21.chord.Chord A4 D5 A2> 111.5
# <music21.chord.Chord C5 E5 A2> 113.0
# <music21.chord.Chord D5 F#5 A2> 114.0
# <music21.chord.Chord C5 E5 A2> 115.0
# <music21.chord.Chord D5 F#5 A2> 116.5
# <music21.chord.Chord E5 G5 A2> 118.0
# <music21.chord.Chord F#5 A5 A2> 119.0
# <music21.note.Note A> 120.0
# <music21.note.Note E> 120.0
# <music21.note.Note A> 120.0
# <music21.note.Note A> 121.5
# <music21.chord.Chord E4 A2> 123.0
# <music21.chord.Chord D4 A2> 124.0
# <music21.note.Note E> 125.0
# <music21.note.Note G> 125.0
# <music21.note.Note A> 125.0
# <music21.note.Note A> 126.5
# <music21.note.Note A> 128.0
# <music21.chord.Chord G4 A2> 129.0
# <music21.chord.Chord F#4 D3> 130.0
# <music21.note.Note A> 130.0
# <music21.note.Note A> 131.5
# <music21.note.Note A> 133.0
# <music21.note.Note A> 134.0
# <music21.note.Note D> 135.0
# <music21.note.Note F> 135.0
# <music21.note.Note A> 135.0
# <music21.note.Note A> 136.5
# <music21.chord.Chord E4 A2> 138.0
# <music21.chord.Chord F4 A2> 139.0
# <music21.chord.Chord E4 E3> 140.0
# <music21.note.Note A> 140.0
# <music21.note.Note A> 141.5
# <music21.note.Note A> 143.0
# <music21.note.Note A> 144.0
# <music21.chord.Chord A3 G3> 145.0
# <music21.note.Note A> 145.0
# <music21.note.Note A> 146.5
# <music21.chord.Chord A4 A2> 148.0
# <music21.chord.Chord G4 G2> 149.0
# <music21.chord.Chord A4 F#3> 150.0
# <music21.note.Note D> 150.0
# <music21.note.Note A> 150.0
# <music21.note.Note A> 151.5
# <music21.chord.Chord C4 A2> 153.0
# <music21.chord.Chord B3 A2> 154.0
# <music21.chord.Chord C4 A4> 155.0
# <music21.note.Note F> 155.0
# <music21.note.Note A> 155.0
# <music21.note.Note A> 156.5
# <music21.note.Note A> 158.0
# <music21.note.Note A> 159.0
# <music21.note.Note A> 160.0
# <music21.note.Note E> 160.0
# <music21.note.Note A> 160.0
# <music21.note.Note A> 161.5
# <music21.chord.Chord E5 A2> 163.0
# <music21.chord.Chord D5 A2> 164.0
# <music21.note.Note E> 165.0
# <music21.note.Note G> 165.0
# <music21.note.Note A> 165.0
# <music21.note.Note A> 166.5
# <music21.note.Note A> 168.0
# <music21.chord.Chord G5 A2> 169.0
# <music21.chord.Chord F#5 D3> 170.0
# <music21.note.Note A> 170.0
# <music21.note.Note A> 171.5
# <music21.note.Note A> 173.0
# <music21.note.Note A> 174.0
# <music21.note.Note D> 175.0
# <music21.note.Note F> 175.0
# <music21.note.Note A> 175.0
# <music21.note.Note A> 176.5
# <music21.chord.Chord F5 A2> 178.0
# <music21.chord.Chord G5 A2> 179.0
# <music21.chord.Chord D5 A3 D4> 180.0
# <music21.note.Note A> 180.0
# <music21.note.Note D> 180.0
# <music21.note.Note D> 181.5
# <music21.note.Note D> 183.0
# <music21.note.Note D> 184.0
# <music21.chord.Chord F5 A3 C4> 185.0
# <music21.note.Note D> 185.0
# <music21.note.Note D> 186.5
# <music21.note.Note D> 188.0
# <music21.note.Note D> 189.0
# <music21.chord.Chord B4 G5 G3 B3> 190.0
# <music21.note.Note D> 190.0
# <music21.note.Note D> 191.5
# <music21.note.Note D> 193.0
# <music21.note.Note D> 194.0
# <music21.chord.Chord B-4 F5 B-3 D4> 195.0
# <music21.note.Note D> 195.0
# <music21.note.Note D> 196.5
# <music21.note.Note D> 198.0
# <music21.note.Note D> 199.0
# <music21.note.Note A> 200.0
# <music21.note.Note E> 200.0
# <music21.note.Note A> 200.0
# <music21.note.Note A> 201.5
# <music21.chord.Chord E4 A2> 203.0
# <music21.chord.Chord D4 A2> 204.0
# <music21.note.Note E> 205.0
# <music21.note.Note G> 205.0
# <music21.note.Note A> 205.0
# <music21.note.Note A> 206.5
# <music21.note.Note A> 208.0
# <music21.chord.Chord G4 A2> 209.0
# <music21.chord.Chord F#4 D3> 210.0
# <music21.note.Note A> 210.0
# <music21.note.Note A> 211.5
# <music21.note.Note A> 213.0
# <music21.note.Note A> 214.0
# <music21.note.Note D> 215.0
# <music21.note.Note F> 215.0
# <music21.note.Note A> 215.0
# <music21.note.Note A> 216.5
# <music21.chord.Chord C4 A2> 218.0
# <music21.chord.Chord B3 A2> 219.0
# <music21.chord.Chord C5 F3> 220.0
# <music21.note.Note F> 220.0
# <music21.note.Note F> 221.5
# <music21.note.Note F> 223.0
# <music21.note.Note F> 224.0
# <music21.chord.Chord D5 F3> 225.0
# <music21.note.Note F> 225.0
# <music21.note.Note F> 226.5
# <music21.note.Note F> 228.0
# <music21.note.Note F> 229.0
# <music21.chord.Chord E5 F3> 230.0
# <music21.note.Note F> 230.0
# <music21.note.Note F> 231.5
# <music21.note.Note F> 233.0
# <music21.note.Note F> 234.0
# <music21.chord.Chord F5 F3> 235.0
# <music21.note.Note F> 235.0
# <music21.note.Note F> 236.5
# <music21.note.Note F> 238.0
# <music21.note.Note F> 239.0
# <music21.note.Note A> 240.0
# <music21.note.Note E> 240.0
# <music21.note.Note A> 240.0
# <music21.note.Note B> 241.5
# <music21.note.Note A> 241.5
# <music21.chord.Chord C5 A2> 243.0
# <music21.chord.Chord D5 A2> 244.0
# <music21.note.Note A> 245.0
# <music21.note.Note E> 245.0
# <music21.note.Note A> 245.0
# <music21.note.Note E> 245.5
# <music21.note.Note E> 246.0
# <music21.chord.Chord E-4 A2> 246.5
# <music21.note.Note E-> 247.0
# <music21.note.Note E-> 247.5
# <music21.note.Note D> 248.0
# <music21.note.Note A> 248.0
# <music21.note.Note D> 248.5
# <music21.chord.Chord C4 A2> 249.0
# <music21.chord.Chord F4 A4> 250.0
# <music21.note.Note A> 250.0
# <music21.note.Note F> 251.5
# <music21.note.Note B> 251.5
# <music21.note.Note A> 251.5
# <music21.note.Note D> 252.5
# <music21.chord.Chord C5 E5 A2> 253.0
# <music21.chord.Chord D5 B5 A2> 254.0
# <music21.chord.Chord F5 D6> 255.0
# <music21.note.Note A> 255.0
# <music21.note.Note D> 256.0
# <music21.note.Note A> 256.5
# <music21.note.Note C> 257.0
# <music21.chord.Chord B4 A2> 258.0
# <music21.chord.Chord A4 A2> 259.0
# <music21.chord.Chord D5 B5> 260.0
# <music21.note.Note G> 260.0
# <music21.chord.Chord E5 C6> 261.0
# <music21.chord.Chord D5 B5> 261.5
# <music21.chord.Chord C5 A5> 262.5
# <music21.chord.Chord B4 G5> 263.0
# <music21.chord.Chord C5 A5> 264.0
# <music21.chord.Chord B4 G5> 264.5
# <music21.chord.Chord F4 D5> 265.5
# <music21.chord.Chord A4 F5> 266.0
# <music21.note.Note G> 266.0
# <music21.note.Note D> 266.5
# <music21.chord.Chord G4 E5> 267.0
# <music21.note.Note E> 267.5
# <music21.chord.Chord F4 D5> 268.0
# <music21.note.Note F> 268.5
# <music21.chord.Chord D4 B4> 269.0
# <music21.note.Note G> 269.5
# <music21.chord.Chord E4 C5 A2> 270.0
# <music21.chord.Chord A4 D5 A2> 271.5
# <music21.chord.Chord C5 E5 A2> 273.0
# <music21.chord.Chord D5 F#5 A2> 274.0
# <music21.chord.Chord C5 E5 A2> 275.0
# <music21.chord.Chord D5 F#5 A2> 276.5
# <music21.chord.Chord E5 G5 A2> 278.0
# <music21.chord.Chord F#5 A5 A2> 279.0
# <music21.note.Note A> 280.0
# <music21.note.Note E> 280.0
# <music21.note.Note A> 280.0
# <music21.note.Note B> 281.5
# <music21.note.Note A> 281.5
# <music21.chord.Chord C5 A2> 283.0
# <music21.chord.Chord D5 A2> 284.0
# <music21.note.Note A> 285.0
# <music21.note.Note E> 285.0
# <music21.note.Note A> 285.0
# <music21.note.Note E> 285.5
# <music21.note.Note E> 286.0
# <music21.chord.Chord E-4 A2> 286.5
# <music21.note.Note E-> 287.0
# <music21.note.Note E-> 287.5
# <music21.note.Note D> 288.0
# <music21.note.Note A> 288.0
# <music21.note.Note D> 288.5
# <music21.chord.Chord C4 A2> 289.0
# <music21.chord.Chord F4 A4> 290.0
# <music21.note.Note A> 290.0
# <music21.note.Note F> 291.5
# <music21.note.Note B> 291.5
# <music21.note.Note A> 291.5
# <music21.note.Note D> 292.5
# <music21.chord.Chord C5 E5 A2> 293.0
# <music21.chord.Chord D5 B5 A2> 294.0
# <music21.chord.Chord F5 D6> 295.0
# <music21.note.Note A> 295.0
# <music21.note.Note A> 296.5
# <music21.note.Note A> 297.5
# <music21.note.Note A> 298.0
# <music21.note.Note E> 299.0
# <music21.note.Note B> 300.0
# <music21.note.Note B> 300.0
# <music21.note.Note G> 300.0
# <music21.note.Note B-> 300.5
# <music21.note.Note B> 301.0
# <music21.note.Note C> 301.5
# <music21.note.Note A> 301.5
# <music21.note.Note B> 302.0
# <music21.note.Note C> 302.5
# <music21.note.Note D> 303.0
# <music21.note.Note G> 303.0
# <music21.note.Note G> 303.5
# <music21.note.Note A> 304.0
# <music21.note.Note D> 304.0
# <music21.note.Note F#> 304.5
# <music21.note.Note G> 305.0
# <music21.note.Note D> 305.0
# <music21.note.Note G> 305.0
# <music21.note.Note F#> 305.5
# <music21.note.Note G> 306.0
# <music21.note.Note A> 306.5
# <music21.note.Note C> 306.5
# <music21.note.Note B> 307.0
# <music21.note.Note A> 307.5
# <music21.note.Note B> 308.0
# <music21.note.Note B> 308.0
# <music21.note.Note G> 308.0
# <music21.note.Note C> 308.5
# <music21.note.Note D> 309.0
# <music21.note.Note G> 309.0
# <music21.note.Note B> 309.5
# <music21.chord.Chord E5 C6 A2> 310.0
# <music21.chord.Chord A4 D5 A2> 311.5
# <music21.chord.Chord C5 E5 A2> 313.0
# <music21.chord.Chord D5 F#5 A2> 314.0
# <music21.chord.Chord C5 E5 A2> 315.0
# <music21.chord.Chord D5 F#5 A2> 316.5
# <music21.chord.Chord E5 G5 A2> 318.0
# <music21.chord.Chord F#5 A5 A2> 319.0
# <music21.note.Note A> 320.0
# <music21.note.Note E> 320.0
# <music21.note.Note A> 320.0
# <music21.note.Note A> 321.5
# <music21.chord.Chord E4 A2> 323.0
# <music21.chord.Chord D4 A2> 324.0
# <music21.note.Note E> 325.0
# <music21.note.Note G> 325.0
# <music21.note.Note A> 325.0
# <music21.note.Note A> 326.5
# <music21.note.Note A> 328.0
# <music21.chord.Chord G4 A2> 329.0
# <music21.chord.Chord F#4 D3> 330.0
# <music21.note.Note A> 330.0
# <music21.note.Note A> 331.5
# <music21.note.Note A> 333.0
# <music21.note.Note A> 334.0
# <music21.note.Note D> 335.0
# <music21.note.Note F> 335.0
# <music21.note.Note A> 335.0
# <music21.note.Note A> 336.5
# <music21.chord.Chord E4 A2> 338.0
# <music21.chord.Chord F4 A2> 339.0
# <music21.chord.Chord E4 E3> 340.0
# <music21.note.Note A> 340.0
# <music21.note.Note A> 341.5
# <music21.note.Note A> 343.0
# <music21.note.Note A> 344.0
# <music21.chord.Chord A3 G3> 345.0
# <music21.note.Note A> 345.0
# <music21.note.Note A> 346.5
# <music21.chord.Chord A4 A2> 348.0
# <music21.chord.Chord G4 G2> 349.0
# <music21.chord.Chord A4 F#3> 350.0
# <music21.note.Note D> 350.0
# <music21.note.Note A> 350.0
# <music21.note.Note A> 351.5
# <music21.chord.Chord C4 A2> 353.0
# <music21.chord.Chord B3 A2> 354.0
# <music21.chord.Chord C4 A4> 355.0
# <music21.note.Note F> 355.0
# <music21.note.Note A> 355.0
# <music21.note.Note A> 356.5
# <music21.note.Note A> 358.0
# <music21.note.Note A> 359.0
# <music21.note.Note A> 360.0
# <music21.note.Note E> 360.0
# <music21.note.Note A> 360.0
# <music21.note.Note A> 361.5
# <music21.chord.Chord E5 A2> 363.0
# <music21.chord.Chord D5 A2> 364.0
# <music21.note.Note E> 365.0
# <music21.note.Note G> 365.0
# <music21.note.Note A> 365.0
# <music21.note.Note A> 366.5
# <music21.note.Note A> 368.0
# <music21.chord.Chord G5 A2> 369.0
# <music21.chord.Chord F#5 D3> 370.0
# <music21.note.Note A> 370.0
# <music21.note.Note A> 371.5
# <music21.note.Note A> 373.0
# <music21.note.Note A> 374.0
# <music21.note.Note D> 375.0
# <music21.note.Note F> 375.0
# <music21.note.Note A> 375.0
# <music21.note.Note A> 376.5
# <music21.chord.Chord F5 A2> 378.0
# <music21.chord.Chord G5 A2> 379.0
# <music21.chord.Chord D5 A3 D4> 380.0
# <music21.note.Note A> 380.0
# <music21.note.Note D> 380.0
# <music21.note.Note D> 381.5
# <music21.note.Note D> 383.0
# <music21.note.Note D> 384.0
# <music21.chord.Chord F5 A3 C4> 385.0
# <music21.note.Note D> 385.0
# <music21.note.Note D> 386.5
# <music21.note.Note D> 388.0
# <music21.note.Note D> 389.0
# <music21.chord.Chord B4 G5 G3 B3> 390.0
# <music21.note.Note D> 390.0
# <music21.note.Note D> 391.5
# <music21.note.Note D> 393.0
# <music21.note.Note D> 394.0
# <music21.chord.Chord B-4 F5 B-3 D4> 395.0
# <music21.note.Note D> 395.0
# <music21.note.Note D> 396.5
# <music21.note.Note D> 398.0
# <music21.note.Note D> 399.0
# <music21.note.Note A> 400.0
# <music21.note.Note E> 400.0
# <music21.note.Note A> 400.0
# <music21.note.Note A> 401.5
# <music21.chord.Chord E4 A2> 403.0
# <music21.chord.Chord D4 A2> 404.0
# <music21.note.Note E> 405.0
# <music21.note.Note G> 405.0
# <music21.note.Note A> 405.0
# <music21.note.Note A> 406.5
# <music21.note.Note A> 408.0
# <music21.chord.Chord G4 A2> 409.0
# <music21.chord.Chord F#4 D3> 410.0
# <music21.note.Note A> 410.0
# <music21.note.Note A> 411.5
# <music21.note.Note A> 413.0
# <music21.note.Note A> 414.0
# <music21.note.Note D> 415.0
# <music21.note.Note F> 415.0
# <music21.note.Note A> 415.0
# <music21.note.Note A> 416.5
# <music21.chord.Chord C4 A2> 418.0
# <music21.chord.Chord B3 A2> 419.0
# <music21.chord.Chord C5 F3> 420.0
# <music21.note.Note F> 420.0
# <music21.note.Note F> 421.5
# <music21.note.Note F> 423.0
# <music21.note.Note F> 424.0
# <music21.chord.Chord D5 F3> 425.0
# <music21.note.Note F> 425.0
# <music21.note.Note F> 426.5
# <music21.note.Note F> 428.0
# <music21.note.Note F> 429.0
# <music21.chord.Chord E5 F3> 430.0
# <music21.note.Note F> 430.0
# <music21.note.Note F> 431.5
# <music21.note.Note F> 433.0
# <music21.note.Note F> 434.0
# <music21.chord.Chord F5 F3> 435.0
# <music21.note.Note F> 435.0
# <music21.note.Note F> 436.5
# <music21.note.Note F> 438.0
# <music21.note.Note F> 439.0
# <music21.note.Note A> 440.0
# <music21.note.Note E> 440.0
# <music21.note.Note A> 440.0
# <music21.note.Note B> 441.5
# <music21.note.Note A> 441.5
# <music21.chord.Chord C5 A2> 443.0
# <music21.chord.Chord D5 A2> 444.0
# <music21.note.Note A> 445.0
# <music21.note.Note E> 445.0
# <music21.note.Note A> 445.0
# <music21.note.Note E> 445.5
# <music21.note.Note E> 446.0
# <music21.chord.Chord E-4 A2> 446.5
# <music21.note.Note E-> 447.0
# <music21.note.Note E-> 447.5
# <music21.note.Note D> 448.0
# <music21.note.Note A> 448.0
# <music21.note.Note D> 448.5
# <music21.chord.Chord C4 A2> 449.0
# <music21.chord.Chord F4 A4> 450.0
# <music21.note.Note A> 450.0
# <music21.note.Note F> 451.5
# <music21.note.Note B> 451.5
# <music21.note.Note A> 451.5
# <music21.note.Note D> 452.5
# <music21.chord.Chord C5 E5 A2> 453.0
# <music21.chord.Chord D5 B5 A2> 454.0
# <music21.chord.Chord F5 D6> 455.0
# <music21.note.Note A> 455.0
# <music21.note.Note D> 456.0
# <music21.note.Note A> 456.5
# <music21.note.Note C> 457.0
# <music21.chord.Chord B4 A2> 458.0
# <music21.chord.Chord A4 A2> 459.0

# %%
notes_to_parse[0]
# Out:
# <music21.chord.Chord A3 D4>

# %%
notes_demo= []
for element in notes_to_parse:
    # If the element is a Note, then store it's pitch
    if isinstance(element, note.Note): 
        notes_demo.append(str(element.pitch))

    # If the element is a Chord, split each note of the chord and join them with dot
    elif isinstance(element, chord.Chord): 
        notes_demo.append('+'.join(str(n) for n in element.normalOrder))

# %%
isinstance(notes_to_parse[1], note.Note)
# Out:
# True

# %%
notes_to_parse[0].normalOrder
# Out:
# [9, 2]

# %%
notes_to_parse[0]
# Out:
# <music21.chord.Chord A3 D4>

# %%
notes_demo
# Out:
# ['9+2',
#  'D3',
#  '9+2',
#  '9+2',
#  '9+2',
#  '9+2',
#  '9+2',
#  '9+0+2',
#  'D3',
#  '9+0+2',
#  '9+0+2',
#  '9+0+2',
#  '9+0+2',
#  '9+0+2',
#  '11+2',
#  'D3',
#  '11+2',
#  '11+2',
#  '11+2',
#  '11+2',
#  '11+2',
#  '10+2',
#  'D3',
#  '10+2',
#  '10+2',
#  '10+2',
#  '10+2',
#  '10+2',
#  '9+2',
#  'D3',
#  '9+2',
#  '9+2',
#  '9+2',
#  '9+2',
#  '9+2',
#  '9+0+2',
#  'D3',
#  '9+0+2',
#  '9+0+2',
#  '9+0+2',
#  '9+0+2',
#  '9+0+2',
#  '7+11+2',
#  'D3',
#  '7+11+2',
#  '7+11+2',
#  '7+11+2',
#  '7+11+2',
#  '7+11+2',
#  '10+2+5',
#  'D3',
#  '10+2+5',
#  '10+2+5',
#  '10+2+5',
#  '10+2+5',
#  '10+2+5',
#  'A4',
#  'E4',
#  'A2',
#  'B4',
#  'A2',
#  '9+0',
#  '9+2',
#  'A4',
#  'E4',
#  'A2',
#  'E4',
#  'E4',
#  '3+9',
#  'E-4',
#  'E-4',
#  'D4',
#  'A2',
#  'D4',
#  '9+0',
#  '5+9',
#  'A2',
#  'F5',
#  'B4',
#  'A2',
#  'D5',
#  '9+0+4',
#  '9+11+2',
#  '2+5',
#  'A2',
#  'D5',
#  'A2',
#  'C5',
#  '9+11',
#  '9',
#  '11+2',
#  'G2',
#  '0+4',
#  '11+2',
#  '9+0',
#  '7+11',
#  '9+0',
#  '7+11',
#  '2+5',
#  '5+9',
#  'G2',
#  'D3',
#  '4+7',
#  'E3',
#  '2+5',
#  'F3',
#  '11+2',
#  'G3',
#  '9+0+4',
#  '9+2',
#  '9+0+4',
#  '2+6+9',
#  '9+0+4',
#  '2+6+9',
#  '4+7+9',
#  '6+9',
#  'A4',
#  'E4',
#  'A2',
#  'B4',
#  'A2',
#  '9+0',
#  '9+2',
#  'A4',
#  'E4',
#  'A2',
#  'E4',
#  'E4',
#  '3+9',
#  'E-4',
#  'E-4',
#  'D4',
#  'A2',
#  'D4',
#  '9+0',
#  '5+9',
#  'A2',
#  'F5',
#  'B4',
#  'A2',
#  'D5',
#  '9+0+4',
#  '9+11+2',
#  '2+5',
#  'A2',
#  'A2',
#  'A2',
#  'A2',
#  'E3',
#  'B4',
#  'B3',
#  'G3',
#  'B-4',
#  'B4',
#  'C5',
#  'A3',
#  'B4',
#  'C5',
#  'D5',
#  'G2',
#  'G5',
#  'A5',
#  'D3',
#  'F#5',
#  'G5',
#  'D4',
#  'G3',
#  'F#5',
#  'G5',
#  'A5',
#  'C4',
#  'B5',
#  'A5',
#  'B5',
#  'B3',
#  'G3',
#  'C6',
#  'D6',
#  'G2',
#  'B5',
#  '9+0+4',
#  '9+2',
#  '9+0+4',
#  '2+6+9',
#  '9+0+4',
#  '2+6+9',
#  '4+7+9',
#  '6+9',
#  'A3',
#  'E3',
#  'A2',
#  'A2',
#  '4+9',
#  '9+2',
#  'E4',
#  'G3',
#  'A2',
#  'A2',
#  'A2',
#  '7+9',
#  '2+6',
#  'A2',
#  'A2',
#  'A2',
#  'A2',
#  'D4',
#  'F3',
#  'A2',
#  'A2',
#  '4+9',
#  '5+9',
#  '4',
#  'A2',
#  'A2',
#  'A2',
#  'A2',
#  '7+9',
#  'A2',
#  'A2',
#  '9',
#  '7',
#  '6+9',
#  'D4',
#  'A2',
#  'A2',
#  '9+0',
#  '9+11',
#  '9+0',
#  'F3',
#  'A2',
#  'A2',
#  'A2',
#  'A2',
#  'A4',
#  'E3',
#  'A2',
#  'A2',
#  '4+9',
#  '9+2',
#  'E5',
#  'G3',
#  'A2',
#  'A2',
#  'A2',
#  '7+9',
#  '2+6',
#  'A2',
#  'A2',
#  'A2',
#  'A2',
#  'D5',
#  'F3',
#  'A2',
#  'A2',
#  '5+9',
#  '7+9',
#  '9+2',
#  'A5',
#  'D3',
#  'D3',
#  'D3',
#  'D3',
#  '5+9+0',
#  'D3',
#  'D3',
#  'D3',
#  'D3',
#  '7+11',
#  'D3',
#  'D3',
#  'D3',
#  'D3',
#  '10+2+5',
#  'D3',
#  'D3',
#  'D3',
#  'D3',
#  'A3',
#  'E3',
#  'A2',
#  'A2',
#  '4+9',
#  '9+2',
#  'E4',
#  'G3',
#  'A2',
#  'A2',
#  'A2',
#  '7+9',
#  '2+6',
#  'A2',
#  'A2',
#  'A2',
#  'A2',
#  'D4',
#  'F3',
#  'A2',
#  'A2',
#  '9+0',
#  '9+11',
#  '0+5',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  '2+5',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  '4+5',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  '5',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  'A4',
#  'E4',
#  'A2',
#  'B4',
#  'A2',
#  '9+0',
#  '9+2',
#  'A4',
#  'E4',
#  'A2',
#  'E4',
#  'E4',
#  '3+9',
#  'E-4',
#  'E-4',
#  'D4',
#  'A2',
#  'D4',
#  '9+0',
#  '5+9',
#  'A2',
#  'F5',
#  'B4',
#  'A2',
#  'D5',
#  '9+0+4',
#  '9+11+2',
#  '2+5',
#  'A2',
#  'D5',
#  'A2',
#  'C5',
#  '9+11',
#  '9',
#  '11+2',
#  'G2',
#  '0+4',
#  '11+2',
#  '9+0',
#  '7+11',
#  '9+0',
#  '7+11',
#  '2+5',
#  '5+9',
#  'G2',
#  'D3',
#  '4+7',
#  'E3',
#  '2+5',
#  'F3',
#  '11+2',
#  'G3',
#  '9+0+4',
#  '9+2',
#  '9+0+4',
#  '2+6+9',
#  '9+0+4',
#  '2+6+9',
#  '4+7+9',
#  '6+9',
#  'A4',
#  'E4',
#  'A2',
#  'B4',
#  'A2',
#  '9+0',
#  '9+2',
#  'A4',
#  'E4',
#  'A2',
#  'E4',
#  'E4',
#  '3+9',
#  'E-4',
#  'E-4',
#  'D4',
#  'A2',
#  'D4',
#  '9+0',
#  '5+9',
#  'A2',
#  'F5',
#  'B4',
#  'A2',
#  'D5',
#  '9+0+4',
#  '9+11+2',
#  '2+5',
#  'A2',
#  'A2',
#  'A2',
#  'A2',
#  'E3',
#  'B4',
#  'B3',
#  'G3',
#  'B-4',
#  'B4',
#  'C5',
#  'A3',
#  'B4',
#  'C5',
#  'D5',
#  'G2',
#  'G5',
#  'A5',
#  'D3',
#  'F#5',
#  'G5',
#  'D4',
#  'G3',
#  'F#5',
#  'G5',
#  'A5',
#  'C4',
#  'B5',
#  'A5',
#  'B5',
#  'B3',
#  'G3',
#  'C6',
#  'D6',
#  'G2',
#  'B5',
#  '9+0+4',
#  '9+2',
#  '9+0+4',
#  '2+6+9',
#  '9+0+4',
#  '2+6+9',
#  '4+7+9',
#  '6+9',
#  'A3',
#  'E3',
#  'A2',
#  'A2',
#  '4+9',
#  '9+2',
#  'E4',
#  'G3',
#  'A2',
#  'A2',
#  'A2',
#  '7+9',
#  '2+6',
#  'A2',
#  'A2',
#  'A2',
#  'A2',
#  'D4',
#  'F3',
#  'A2',
#  'A2',
#  '4+9',
#  '5+9',
#  '4',
#  'A2',
#  'A2',
#  'A2',
#  'A2',
#  '7+9',
#  'A2',
#  'A2',
#  '9',
#  '7',
#  '6+9',
#  'D4',
#  'A2',
#  'A2',
#  '9+0',
#  '9+11',
#  '9+0',
#  'F3',
#  'A2',
#  'A2',
#  'A2',
#  'A2',
#  'A4',
#  'E3',
#  'A2',
#  'A2',
#  '4+9',
#  '9+2',
#  'E5',
#  'G3',
#  'A2',
#  'A2',
#  'A2',
#  '7+9',
#  '2+6',
#  'A2',
#  'A2',
#  'A2',
#  'A2',
#  'D5',
#  'F3',
#  'A2',
#  'A2',
#  '5+9',
#  '7+9',
#  '9+2',
#  'A5',
#  'D3',
#  'D3',
#  'D3',
#  'D3',
#  '5+9+0',
#  'D3',
#  'D3',
#  'D3',
#  'D3',
#  '7+11',
#  'D3',
#  'D3',
#  'D3',
#  'D3',
#  '10+2+5',
#  'D3',
#  'D3',
#  'D3',
#  'D3',
#  'A3',
#  'E3',
#  'A2',
#  'A2',
#  '4+9',
#  '9+2',
#  'E4',
#  'G3',
#  'A2',
#  'A2',
#  'A2',
#  '7+9',
#  '2+6',
#  'A2',
#  'A2',
#  'A2',
#  'A2',
#  'D4',
#  'F3',
#  'A2',
#  'A2',
#  '9+0',
#  '9+11',
#  '0+5',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  '2+5',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  '4+5',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  '5',
#  'F2',
#  'F2',
#  'F2',
#  'F2',
#  'A4',
#  'E4',
#  'A2',
#  'B4',
#  'A2',
#  '9+0',
#  '9+2',
#  'A4',
#  'E4',
#  'A2',
#  'E4',
#  'E4',
#  '3+9',
#  'E-4',
#  'E-4',
#  'D4',
#  'A2',
#  'D4',
#  '9+0',
#  '5+9',
#  'A2',
#  'F5',
#  'B4',
#  'A2',
#  'D5',
#  '9+0+4',
#  '9+11+2',
#  '2+5',
#  'A2',
#  'D5',
#  'A2',
#  'C5',
#  '9+11',
#  '9']

# %%
len(notes_demo)
# Out:
# 618

# %%
len(set(notes_demo))
# Out:
# 55

# %%
np.unique(notes_demo, return_counts=True)
# Out:
# (array(['0+4', '0+5', '10+2', '10+2+5', '11+2', '2+5', '2+6', '2+6+9',
#         '3+9', '4', '4+5', '4+7', '4+7+9', '4+9', '5', '5+9', '5+9+0',
#         '6+9', '7', '7+11', '7+11+2', '7+9', '9', '9+0', '9+0+2', '9+0+4',
#         '9+11', '9+11+2', '9+2', 'A2', 'A3', 'A4', 'A5', 'B-4', 'B3', 'B4',
#         'B5', 'C4', 'C5', 'C6', 'D3', 'D4', 'D5', 'D6', 'E-4', 'E3', 'E4',
#         'E5', 'F#5', 'F2', 'F3', 'F5', 'G2', 'G3', 'G5'], dtype='<U6'),
#  array([  2,   2,   6,   8,  12,  11,   6,   8,   5,   2,   2,   2,   4,
#           8,   2,  11,   2,   6,   2,   6,   6,  10,   5,  20,  12,  17,
#           7,   5,  29, 134,   6,  12,   8,   2,   4,  16,   6,   2,   7,
#           2,  44,  18,  12,   2,  10,  10,  24,   2,   4,  32,  10,   5,
#           8,  14,   6]))

# %%
notes = []


for file in glob.glob("midi_songs/*.mid"):
    midi = converter.parse(file) #convert the file into stream.Score Object

    print("Parsing %s" % file)

    notes_to_parse = None  
    
    # unroll / flat the elements (notes/chords) into the list, because elements are sometimes in list of list form.
    notes_to_parse = midi.flat.notes   
    
    
    # At this point, we have notes_to_parse, which is a Iterator for all the Notes/Chords
    
    for element in notes_to_parse:
        
        # If the element is a Note, then store it's pitch
        if isinstance(element, note.Note): 
            notes.append(str(element.pitch))
            
        # If the element is a Chord, split each note of the chord and join them with +
        elif isinstance(element, chord.Chord): 
            notes.append('+'.join(str(n) for n in element.normalOrder))
# Out:
# Parsing midi_songs/Rachel_Piano_tempofix.mid
# Parsing midi_songs/ff11_awakening_piano.mid
# Parsing midi_songs/Eternal_Harvest.mid
# Parsing midi_songs/electric_de_chocobo.mid
# Parsing midi_songs/Finalfantasy6fanfarecomplete.mid
# Parsing midi_songs/FF3_Battle_(Piano).mid
# Parsing midi_songs/ViviinAlexandria.mid
# Parsing midi_songs/waltz_de_choco.mid
# Parsing midi_songs/great_war.mid
# Parsing midi_songs/Oppressed.mid
# Parsing midi_songs/path_of_repentance.mid
# Parsing midi_songs/goldsaucer.mid
# Parsing midi_songs/ultimafro.mid
# Parsing midi_songs/pkelite4.mid
# Parsing midi_songs/decisive.mid
# Parsing midi_songs/gerudo.mid
# Parsing midi_songs/FF6epitaph_piano.mid
# Parsing midi_songs/sera_.mid
# Parsing midi_songs/sandy.mid
# Parsing midi_songs/tpirtsd-piano.mid
# Parsing midi_songs/Ff7-Cinco.mid
# Parsing midi_songs/Rydia_pc.mid
# Parsing midi_songs/In_Zanarkand.mid
# Parsing midi_songs/Suteki_Da_Ne_(Piano_Version).mid
# Parsing midi_songs/figaro.mid
# Parsing midi_songs/Kingdom_Hearts_Dearly_Beloved.mid
# Parsing midi_songs/traitor.mid
# Parsing midi_songs/DOS.mid
# Parsing midi_songs/Gold_Silver_Rival_Battle.mid
# Parsing midi_songs/ultros.mid
# Parsing midi_songs/FF3_Third_Phase_Final_(Piano).mid
# Parsing midi_songs/balamb.mid
# Parsing midi_songs/roseofmay-piano.mid
# Parsing midi_songs/Kingdom_Hearts_Traverse_Town.mid
# Parsing midi_songs/Fierce_Battle_(Piano).mid
# Parsing midi_songs/relmstheme-piano.mid
# Parsing midi_songs/Final_Fantasy_7_-_Judgement_Day_Piano.mid
# Parsing midi_songs/Zelda_Overworld.mid
# Parsing midi_songs/braska.mid
# Parsing midi_songs/ff4pclov.mid
# Parsing midi_songs/JENOVA.mid
# Parsing midi_songs/ff6shap.mid
# Parsing midi_songs/0fithos.mid
# Parsing midi_songs/sobf.mid
# Parsing midi_songs/ff7-mainmidi.mid
# Parsing midi_songs/Fiend_Battle_(Piano).mid
# Parsing midi_songs/rufus.mid
# Parsing midi_songs/FFX_-_Ending_Theme_(Piano_Version)_-_by_Angel_FF.mid
# Parsing midi_songs/ff7themep.mid
# Parsing midi_songs/HighwindTakestotheSkies.mid
# Parsing midi_songs/FFIX_Piano.mid
# Parsing midi_songs/AT.mid
# Parsing midi_songs/costadsol.mid
# Parsing midi_songs/fortresscondor.mid
# Parsing midi_songs/Ff7-Jenova_Absolute.mid
# Parsing midi_songs/ff4-airship.mid
# Parsing midi_songs/FF8_Shuffle_or_boogie_pc.mid
# Parsing midi_songs/FFIXQuMarshP.mid
# Parsing midi_songs/thenightmarebegins.mid
# Parsing midi_songs/Ff4-BattleLust.mid
# Parsing midi_songs/Fyw_piano.mid
# Parsing midi_songs/ff8-lfp.mid
# Parsing midi_songs/ahead_on_our_way_piano.mid
# Parsing midi_songs/FF4.mid
# Parsing midi_songs/z_aeristhemepiano.mid
# Parsing midi_songs/VincentPiano.mid
# Parsing midi_songs/OTD5YA.mid
# Parsing midi_songs/ff4-town.mid
# Parsing midi_songs/Ff7-One_Winged.mid
# Parsing midi_songs/Cids.mid
# Parsing midi_songs/tifap.mid
# Parsing midi_songs/ff4_piano_collections-main_theme.mid
# Parsing midi_songs/FFVII_BATTLE.mid
# Parsing midi_songs/redwings.mid
# Parsing midi_songs/Still_Alive-1.mid
# Parsing midi_songs/dayafter.mid
# Parsing midi_songs/caitsith.mid
# Parsing midi_songs/Life_Stream.mid
# Parsing midi_songs/thoughts.mid
# Parsing midi_songs/cosmo.mid
# Parsing midi_songs/ff4-fight1.mid
# Parsing midi_songs/Finalfantasy5gilgameshp.mid
# Parsing midi_songs/Final_Fantasy_Matouyas_Cave_Piano.mid
# Parsing midi_songs/lurk_in_dark.mid
# Parsing midi_songs/bcm.mid
# Parsing midi_songs/BlueStone_LastDungeon.mid
# Parsing midi_songs/dontbeafraid.mid
# Parsing midi_songs/FFIII_Edgar_And_Sabin_Piano.mid
# Parsing midi_songs/mining.mid
# Parsing midi_songs/EyesOnMePiano.mid
# Parsing midi_songs/ff1battp.mid
# Parsing midi_songs/8.mid

# %%
with open('data/notes_easy', 'wb') as filepath:
    pickle.dump(notes, filepath)

# %%
with open('data/notes_easy', 'rb') as filepath:
    notes = pickle.load(filepath)

# %%
n_vocab = len(set(notes))

# %%
print("Total notes- ",len(notes))
print("Unique Notes- ",n_vocab)
# Out:
# Total notes-  60498
# Unique Notes-  359

# %%
# notes is a list of all the notes in each music file - 60000
print(notes[:100])
# Out:
# ['G4', 'G5', 'B4', 'E5', 'G4', 'G5', 'F#4', 'F#5', 'E4', 'E5', 'D4', 'D5', 'F#4', 'F#5', 'E4', 'E5', 'C5', 'A3', 'C4', 'E4', 'C5', 'C4', 'B4', 'G3', 'A4', 'B3', 'G4', 'D4', 'B4', 'B3', 'A4', 'F3', 'A3', 'C4', 'E4', 'G4', 'F5', 'F5', 'A4', 'D5', 'F5', 'F5', 'E5', 'E5', 'D5', 'D5', 'C5', 'C5', 'E5', 'E5', 'D5', 'D5', 'B-4', 'B-4', 'C5', 'C5', 'D5', 'D4', 'B-4', 'D4', 'A4', 'D4', 'G4', 'D4', 'G3', 'D4', 'G4', 'D4', 'B-4', 'F4', 'D4', 'C5', 'E4', 'C4', 'D5', 'D3', 'G3', 'A3', 'G4', 'A4', 'G4', 'D4', 'A3', 'D3', 'G5', 'G4', 'A4', 'B-4', 'G4', 'D5', 'D4', 'A4', 'G5', 'B-4', 'G4', 'A5', 'C4', 'G4', 'A4', 'F4']

# %% [markdown]
# ## Prepare Data for LSTM

# %%
#  How many elements LSTM input should consider
sequence_length = 100

# %%
# ALl the unique elements in a sorted manner
pitchnames = sorted(set(item for item in notes))

# %%
# Mapping between note to int value
note_to_int = dict((note, number) for number, note in enumerate(pitchnames))
print(note_to_int)
# Out:
# {'0': 0, '0+1': 1, '0+1+5': 2, '0+1+6': 3, '0+2': 4, '0+2+3+7': 5, '0+2+4+7': 6, '0+2+5': 7, '0+2+6': 8, '0+2+7': 9, '0+3': 10, '0+3+5': 11, '0+3+5+8': 12, '0+3+6': 13, '0+3+6+8': 14, '0+3+6+9': 15, '0+3+7': 16, '0+4': 17, '0+4+5': 18, '0+4+6': 19, '0+4+7': 20, '0+5': 21, '0+5+6': 22, '0+6': 23, '1': 24, '1+2': 25, '1+2+4+6+8+10': 26, '1+2+6': 27, '1+2+6+8': 28, '1+3': 29, '1+3+5': 30, '1+3+5+8': 31, '1+3+6': 32, '1+3+7': 33, '1+3+8': 34, '1+4': 35, '1+4+6': 36, '1+4+6+9': 37, '1+4+7': 38, '1+4+7+10': 39, '1+4+7+9': 40, '1+4+8': 41, '1+5': 42, '1+5+8': 43, '1+5+9': 44, '1+6': 45, '1+7': 46, '10': 47, '10+0': 48, '10+0+2+5': 49, '10+0+3': 50, '10+0+4': 51, '10+0+5': 52, '10+1': 53, '10+1+3': 54, '10+1+3+5+6': 55, '10+1+3+6': 56, '10+1+4': 57, '10+1+4+6': 58, '10+1+5': 59, '10+11': 60, '10+11+3': 61, '10+11+3+5': 62, '10+2': 63, '10+2+3': 64, '10+2+4': 65, '10+2+5': 66, '10+3': 67, '11': 68, '11+0': 69, '11+0+4': 70, '11+0+4+6': 71, '11+0+4+7': 72, '11+0+5': 73, '11+1': 74, '11+1+4': 75, '11+1+4+5': 76, '11+1+5': 77, '11+1+6': 78, '11+2': 79, '11+2+4': 80, '11+2+4+6': 81, '11+2+4+7': 82, '11+2+5': 83, '11+2+5+7': 84, '11+2+6': 85, '11+3': 86, '11+3+5': 87, '11+3+6': 88, '11+4': 89, '11+4+5': 90, '2': 91, '2+3': 92, '2+3+7': 93, '2+3+7+10': 94, '2+3+7+9': 95, '2+4': 96, '2+4+5': 97, '2+4+5+9': 98, '2+4+6+9+11': 99, '2+4+7': 100, '2+4+7+10': 101, '2+4+8': 102, '2+4+9': 103, '2+5': 104, '2+5+7': 105, '2+5+7+10': 106, '2+5+8': 107, '2+5+8+10': 108, '2+5+8+11': 109, '2+5+9': 110, '2+6': 111, '2+6+10': 112, '2+6+7': 113, '2+6+7+9': 114, '2+6+9': 115, '2+7': 116, '2+7+8': 117, '2+8': 118, '3': 119, '3+4': 120, '3+4+8': 121, '3+4+8+10': 122, '3+5': 123, '3+5+10': 124, '3+5+7': 125, '3+5+7+10': 126, '3+5+7+8+11': 127, '3+5+8': 128, '3+5+8+11': 129, '3+6': 130, '3+6+10': 131, '3+6+7': 132, '3+6+8': 133, '3+6+9+11': 134, '3+7': 135, '3+7+10': 136, '3+7+11': 137, '3+7+9': 138, '3+7+9+10': 139, '3+8': 140, '3+8+9': 141, '3+9': 142, '4': 143, '4+10': 144, '4+5': 145, '4+5+7+11': 146, '4+5+9': 147, '4+5+9+0': 148, '4+5+9+11': 149, '4+6': 150, '4+6+10': 151, '4+6+11': 152, '4+6+7': 153, '4+6+8': 154, '4+6+8+11+1': 155, '4+6+9': 156, '4+6+9+11': 157, '4+7': 158, '4+7+10': 159, '4+7+11': 160, '4+7+9': 161, '4+7+9+0': 162, '4+7+9+11': 163, '4+8': 164, '4+8+10': 165, '4+8+11': 166, '4+8+9': 167, '4+8+9+11': 168, '4+9': 169, '4+9+10': 170, '5': 171, '5+10': 172, '5+10+11': 173, '5+11': 174, '5+6': 175, '5+7': 176, '5+7+0': 177, '5+7+10': 178, '5+7+8+0': 179, '5+8': 180, '5+8+0': 181, '5+8+10': 182, '5+8+11': 183, '5+9': 184, '5+9+0': 185, '5+9+11': 186, '5+9+11+0': 187, '6': 188, '6+10': 189, '6+10+0': 190, '6+10+1': 191, '6+10+11': 192, '6+10+11+1': 193, '6+11': 194, '6+11+0': 195, '6+7': 196, '6+7+0': 197, '6+7+11': 198, '6+7+11+2': 199, '6+8': 200, '6+8+0': 201, '6+8+1': 202, '6+8+10': 203, '6+8+10+0+3': 204, '6+8+11': 205, '6+8+11+2': 206, '6+9': 207, '6+9+0': 208, '6+9+0+2': 209, '6+9+1': 210, '6+9+11': 211, '6+9+11+2': 212, '7': 213, '7+0': 214, '7+10': 215, '7+10+0': 216, '7+10+0+3': 217, '7+10+1': 218, '7+10+1+3': 219, '7+10+2': 220, '7+11': 221, '7+11+0': 222, '7+11+2': 223, '7+8': 224, '7+8+0': 225, '7+8+0+3': 226, '7+8+10+2': 227, '7+8+11': 228, '7+9': 229, '7+9+0': 230, '7+9+1': 231, '7+9+11': 232, '7+9+11+2': 233, '7+9+2': 234, '8': 235, '8+0': 236, '8+0+1': 237, '8+0+2': 238, '8+0+3': 239, '8+1': 240, '8+10': 241, '8+10+0': 242, '8+10+1': 243, '8+10+11+1+4': 244, '8+10+11+3': 245, '8+10+2': 246, '8+10+3': 247, '8+11': 248, '8+11+1': 249, '8+11+1+4': 250, '8+11+2': 251, '8+11+3': 252, '8+9': 253, '8+9+1': 254, '8+9+1+3': 255, '8+9+1+4': 256, '8+9+11+1': 257, '8+9+2': 258, '9': 259, '9+0': 260, '9+0+2': 261, '9+0+2+4': 262, '9+0+2+5': 263, '9+0+3': 264, '9+0+3+5': 265, '9+0+4': 266, '9+1': 267, '9+1+4': 268, '9+10': 269, '9+10+2': 270, '9+10+2+4': 271, '9+11': 272, '9+11+0+4': 273, '9+11+1': 274, '9+11+2': 275, '9+11+2+4': 276, '9+11+2+5': 277, '9+11+3': 278, '9+11+4': 279, '9+2': 280, '9+2+3': 281, 'A0': 282, 'A1': 283, 'A2': 284, 'A3': ...

# %%
network_input = []
network_output = []

# %%
# Make the data for LSTM Network
# Each Node will contain 100 input units
# Output will be the next unit in notes list

for i in range(0, len(notes) - sequence_length, 1):
    
    sequence_in = notes[i:i + sequence_length] # contains 100 values 
    sequence_out = notes[i + sequence_length] # containes next values for these 100's
    
    # Since NN works with numeric data only, append the int values for inputs and outputs.
    network_input.append([note_to_int[char] for char in sequence_in])
    network_output.append(note_to_int[sequence_out])

# %%
# No. of examples for our network

n_patterns = len(network_input)
print(n_patterns)
# Out:
# 60398

# %%
# ight now network_input is lits, but reshape it into a format compatible with LSTM layers
network_input = numpy.reshape(network_input, (n_patterns, sequence_length, 1))
print(network_input.shape)
# Out:
# (60398, 100, 1)

# %%
normalised_network_input = network_input/float(n_vocab)

# %%
# network_output are the classes, encode one_hot_vector
network_output = np_utils.to_categorical(network_output)

# %%
print(network_output.shape)
print(normalised_network_input.shape)
# Out:
# (60398, 359)
# (60398, 100, 1)

# %% [markdown]
# ## Create Model

# %%
""" create the structure of the neural network """
model = Sequential()
model.add(LSTM(512,
            input_shape=(network_input.shape[1], network_input.shape[2]),
            return_sequences=True ))
model.add(Dropout(0.3))
model.add(LSTM(512, return_sequences=True))
model.add(Dropout(0.3))
model.add(LSTM(512))
model.add(Dense(256))
model.add(Dropout(0.3))
model.add(Dense(n_vocab))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='rmsprop')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0811 14:04:56.939704 140322256295744 deprecation_wrapper.py:119] From /home/shubham/.conda/envs/my_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0811 14:04:56.983942 140322256295744 deprecation_wrapper.py:119] From /home/shubham/.conda/envs/my_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0811 14:04:56.987332 140322256295744 deprecation_wrapper.py:119] From /home/shubham/.conda/envs/my_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0811 14:04:57.487859 140322256295744 deprecation_wrapper.py:119] From /home/shubham/.conda/envs/my_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0811 14:04:57.494868 140322256295744 deprecation.py:506] From /home/shubham/.conda/envs/my_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0811 14:04:58.731659 140322256295744 deprecation_wrapper.py:119] From /home/shubham/.conda/envs/my_env/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0811 14:04:58.749062 140322256295744 deprecation_wrapper.py:119] From /home/shubham/.conda/envs/my_env/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 100, 512)          1052672
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100, 512)          0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100, 512)          2099200
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100, 512)          0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 512)               2099200
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 359)               92263
# _________________________________________________________________
# activation_1 (Activation)    (None, 359)               0
# =================================================================
# Total params: 5,474,663
# Trainable params: 5,474,663
# Non-trainable params: 0
# _________________________________________________________________

# %%
""" train the neural network """

filepath = "model/weights-improvement-{epoch:02d}-{loss:.4f}-bigger.hdf5"

checkpoint = ModelCheckpoint(
    filepath,
    monitor='loss',
    verbose=0,
    save_best_only=True,
    mode='min')

callbacks_list = [checkpoint]

model_his = model.fit(network_input, network_output, epochs=100, batch_size=64, callbacks=callbacks_list)

# %%
model = load_model("model/weights-improvement-60-1.1406-bigger.hdf5")

# %% [markdown]
# ## Predictions

# %%
#  This is done beacuse we need network_input as list, and we had converted it into ndarray to feed into network
#  so, to get back the list.

sequence_length = 100
network_input = []
for i in range(0, len(notes) - sequence_length, 1):
    sequence_in = notes[i:i + sequence_length]
    network_input.append([note_to_int[char] for char in sequence_in])

# %%
""" Generate notes from the neural network based on a sequence of notes """

# pick a random sequence from the input as a starting point for the prediction
start = numpy.random.randint(0, len(network_input)-1)

# Mapping from int to note
int_to_note = dict((number, note) for number, note in enumerate(pitchnames))

# initial pattern
pattern = network_input[start]
prediction_output = []

# generate 200 notes
for note_index in range(200):
    prediction_input = numpy.reshape(pattern, (1, len(pattern), 1))
    prediction_input = prediction_input / float(n_vocab)

    prediction = model.predict(prediction_input, verbose=0)

    index = numpy.argmax(prediction)
    result = int_to_note[index]
    prediction_output.append(result)

    
    # Remove the first value, and append the recent value.. 
    # This way input is moving forward step-by-step with time..
    pattern.append(index)
    pattern = pattern[1:len(pattern)]

# %%
#  Our newly generated song (mix of chords and notes)
print(prediction_output)
# Out:
# ['C5', '2+5', '2+5', 'F5', '2+5', '2+5', '2+5', 'F5', '2+5', 'C5', '0+5', '2+5', 'F5', '2+5', '2+5', '2+5', '2+5', 'G5', '2+5', '2+5', 'G5', '2+5', '2+5', 'G5', '2+5', '2+5', '2+5', '2+5', '2+5', '2+5', 'F5', '2+5', 'C5', 'F5', '2+5', '2+5', 'G5', '2+5', '2+5', 'F5', '2+5', 'C5', 'F5', '0+5', '2+5', '2+5', '2+5', '0+4', '2+5', 'F5', '2+5', '2+5', 'F5', '2+5', '2+5', 'G5', '2+5', '2+5', '0+5', '2+5', '2+5', '0+5', '0+5', '2+5', '0+5', '2+5', '2+5', '2+5', 'G5', '2+5', '2+5', 'G5', '2+5', '2+5', 'F5', '2+5', '2+5', 'G5', '2+5', '2+5', 'F5', '2+5', '2+5', '2+5', '2+5', '0+5', '0+5', 'F5', '0+5', '0+5', 'F5', 'C5', 'B4', '2+5', '2+5', '2+5', '2+5', '2+5', '0+5', '0+5', 'F5', '0+5', '0+5', 'B4', '0+5', '0+5', '0+5', '2+5', '0+5', '0+5', '0+5', '0+5', 'F5', '0+5', '0+5', '0+5', '0+5', '2+5', '0+5', '0+5', '2+5', '0+5', '0+5', '0+5', '0+5', '0+5', '0+5', '0+5', '0+5', '0+5', 'C5', '0+5', '2+5', '2+5', 'B-2', '0+5', '2+5', 'E3', '0+5', '0+5', 'F#4', '0+5', '0+5', 'E5', '0+5', '0+5', '0+5', '0+5', '0+5', '0+5', '0+5', '0+5', '0+5', 'B-2', 'F#4', 'F4', 'B-2', 'B-2', '0+5', '0+5', '0+5', '10+3', '0+5', '0+5', '0+5', 'B-2', '0+5', '0+5', 'B4', '0+5', '0+5', '0+5', '0+5', 'C3', '0+5', 'F2', 'C3', '0+5', 'C3', '0+4', '0+5', 'B-2', 'E3', 'E3', 'G5', 'B5', 'F5', '2+5', 'G5', 'G5', '0+5', '0+5', '0+5', 'G5', 'E5', 'G5', 'G5', 'G5', 'G5', 'F5']

# %% [markdown]
# ## Create MIDI file

# %%
""" convert the output from the prediction to notes and create a midi file from the notes """

offset = 0 # Time
output_notes = []

# create note and chord objects based on the values generated by the model
for pattern in prediction_output:
    
    # if pattern is a chord
    if ('+' in pattern) or pattern.isdigit():
        notes_in_chord = pattern.split('+') # split all the notes from a chord
        notes = []
        for current_note in notes_in_chord: 
            new_note = note.Note(int(current_note)) # create Note object for each note in the chord
            new_note.storedInstrument = instrument.Piano() 
            notes.append(new_note) # list of Notes()
            
        new_chord = chord.Chord(notes)  # Create the Chord() from the list of notes.
        new_chord.offset = offset # set offset to the element
        output_notes.append(new_chord) 
        
    # if pattern is a note
    else:
        new_note = note.Note(pattern) #  create Note object
        new_note.offset = offset # set offset  (basically timestamp)
        new_note.storedInstrument = instrument.Piano()
        output_notes.append(new_note) 

    # increase offset each iteration so that notes do not stack (time stamp)
    offset += 0.5

# %%
output_notes[:50]
# Out:
# [<music21.note.Note C>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.note.Note F>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.note.Note F>,
#  <music21.chord.Chord D F>,
#  <music21.note.Note C>,
#  <music21.chord.Chord C F>,
#  <music21.chord.Chord D F>,
#  <music21.note.Note F>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.note.Note G>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.note.Note G>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.note.Note G>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.note.Note F>,
#  <music21.chord.Chord D F>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.note.Note G>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.note.Note F>,
#  <music21.chord.Chord D F>,
#  <music21.note.Note C>,
#  <music21.note.Note F>,
#  <music21.chord.Chord C F>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord D F>,
#  <music21.chord.Chord C E>,
#  <music21.chord.Chord D F>,
#  <music21.note.Note F>]

# %%
#  Create a Steam Object from our generated Notes, and write to the file. 
midi_stream = stream.Stream(output_notes)
midi_stream.write('midi', fp='output_songs/test_output.mid')
# Out:
# 'output_songs/test_output.mid'

# %% [markdown]
# ## Let's Play our music file

# %%
midi_stream.show('midi')
# Out:
#                 <div id='midiPlayerDiv419110'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv419110');
#                                mp.base64Load('data:audio/midi;base64,...');
#                         });
#                 </script>
